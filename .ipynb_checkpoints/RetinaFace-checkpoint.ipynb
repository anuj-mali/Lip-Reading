# %% [markdown]
# ## 0. Dependencies

# %%
import torch
from torch import nn

import torchvision
from torchvision.io import read_video

import numpy as np
import pandas as pd 
import os

from ibug.face_alignment import FANPredictor
from ibug.face_detection import RetinaFacePredictor

# %%
# !pip list --format=freeze > requirements_retinaface.txt

# %% [markdown]
# ## 1. Device Agnostic Code

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
sample_path = "data/custom_dataset/VIOLENCE/20240225_092440.mp4"
sample_label = "ABOUT"

# %% [markdown]
# ## 2. Landmarks Detector

# %%
face_detector = RetinaFacePredictor(device=device, threshold=0.8)
landmark_detector = FANPredictor(device=device)

# %%
sample_path = "data/custom_dataset/HAPPENING/WIN_20240225_18_59_58_Pro.mp4"

# %%
from torchvision.io import read_video, write_video

video_frames = read_video(filename=sample_path, pts_unit='sec')[0].numpy()

# %%
# write_video(sample_path, torch.tensor(video_frames.copy()), fps=metadata['video_fps'])

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# import torchvision.io as io
# import torch

# df = pd.read_pickle('dataframe/custom.pkl')
# # Assuming df is your DataFrame and 'video_path' is the column with the video paths
# for index, row in df.iterrows():
#     video_path = row['path']
#     print(index)
#     filename = video_path.split('/')[-1]
#     if filename.startswith('VID'):
#         # Read the video and get the frames
#         video, audio, info = io.read_video(video_path, pts_unit='sec')
    
#         # Get the 10th frame
#         frame = video[9]
    
#         # Display the 10th frame
#         plt.imshow(frame)
#         plt.show()
    
#         # Ask for rotation integer
#         rotation = int(input("Enter rotation integer (1-3): "))
    
#         # Rotate and display the image
#         rotated_frame = np.rot90(frame.numpy(), rotation, axes=[0, 1])
#         plt.imshow(rotated_frame)
#         plt.show()
    
        
#         if rotation != 0:
#             # Rotate all frames
#             rotated_video = np.rot90(video.numpy(), rotation, axes=[1, 2])
    
#             # Save the rotated video
#             io.write_video(video_path, torch.from_numpy(rotated_video.copy()), fps=info["video_fps"])

# %%
# %%time
landmarks = []
for frame in video_frames:
    detected_faces = face_detector(frame, rgb=False)
    face_points, _ = landmark_detector(frame, detected_faces, rgb=True)
    if len(detected_faces) == 0:
        landmarks.append(None)
    else:
        max_id, max_size = 0, 0
        for idx, bbox in enumerate(detected_faces):
            bbox_size = (bbox[2] - bbox[0]) + (bbox[3] - bbox[1])
            if bbox_size > max_size:
                max_id, max_size = idx, bbox_size
        landmarks.append(face_points[max_id])
landmarks
# Out:
# CPU times: user 14 s, sys: 562 ms, total: 14.6 s
# Wall time: 12.6 s
# [array([[ 814.47266,  475.39502],
#         [ 815.4435 ,  529.1881 ],
#         [ 824.1616 ,  586.7888 ],
#         [ 833.18604,  635.85516],
#         [ 851.36414,  688.07294],
#         [ 882.1942 ,  732.14905],
#         [ 915.9433 ,  763.6142 ],
#         [ 959.3751 ,  790.6596 ],
#         [1024.5796 ,  807.2401 ],
#         [1089.8218 ,  790.2891 ],
#         [1132.9529 ,  763.919  ],
#         [1167.2498 ,  733.592  ],
#         [1198.697  ,  687.7196 ],
#         [1214.0957 ,  632.39264],
#         [1221.5574 ,  582.19336],
#         [1227.2036 ,  528.66425],
#         [1228.8787 ,  473.30048],
#         [1080.3811 ,  476.89325],
#         [1102.4528 ,  470.65997],
#         [1127.4951 ,  473.1876 ],
#         [1148.9698 ,  477.61218],
#         [1128.2124 ,  483.3729 ],
#         [1101.3306 ,  482.0089 ],
#         [ 951.8789 ,  668.54736],
#         [ 978.24414,  653.6848 ],
#         [1009.20825,  641.256  ],
#         [1025.9347 ,  643.663  ],
#         [1041.4756 ,  640.4963 ],
#         [1071.1841 ,  650.91986],
#         [1097.7596 ,  662.82733],
#         [1070.7733 ,  676.6882 ],
#         [1048.1799 ,  684.9838 ],
#         [1026.5525 ,  686.21185],
#         [1002.2356 ,  684.7611 ],
#         [ 979.7351 ,  679.3804 ],
#         [ 959.43506,  667.3365 ],
#         [1005.2348 ,  658.3703 ],
#         [1026.2576 ,  657.62366],
#         [1045.8317 ,  657.68134],
#         [1090.2816 ,  661.1096 ],
#         [1046.3295 ,  662.0786 ],
#         [1026.1392 ,  664.2969 ],
#         [1005.3578 ,  663.09045]], dtype=float32),
#  array([[ 814.6086 ,  474.5603 ],
#         [ 815.837  ,  529.2678 ],
#         [ 824.8673 ,  587.6861 ],
#         [ 834.05896,  636.08167],
#         [ 851.88165,  688.6106 ],
#         [ 881.9005 ,  732.5422 ],
#         [ 914.5876 ,  763.5413 ],
#         [ 957.92316,  790.4555 ],
#         [1022.2765 ,  809.016  ],
#         [1087.1667 ,  792.1615 ],
#         [1131.3632 ,  765.09247],
#         [1166.3099 ,  735.1999 ],
#         [1198.0032 ,  688.7996 ],
#         [1213.8118 ,  632.38464],
#         [1220.9775 ,  582.21326],
#         [1228.2319 ,  529.18726],
#         [1230.4043 ,  472.62164],
#         [ 859.2649 ,  430.08282],
#         [ 882.77386,  411.13596],
#         [ 912.234  ,  406.97833],
#         [ 942.4652 ,  407.4758 ],
#         [ 970.5493 ,  412.49606],
#         [1074.9333 ,  412.75305],
#         [1101.6201 ,  409.38675],
#         [1132.6294 ,  409.44916],
#         [1163.7446 ,  415.65457],
#         [1186.9131 ,  432.69202],
#         [1023.72205,  477.44824],
#         [1025.227  ,  514.50336],
#         [1022.4863 ,  547.4529 ],
#         [1021.6189 ,  577.61993],
#         [ 988.55396,  601.3053 ],
#         [1003.9277 ,  602.43256],
#         [1023.93024,  606.38745],
#         [1044.6333 ,  601.56384],
#         [1058.6824 ,  600.0178 ],
#         [ 898.0522 ,  476.6517 ],
#         [ 920.8856 ,  468.8752 ],
#         [ 944.3838 ,  467.8618 ],
#         [ 966.9105 ,  477.18475],
#         [ 946.97455,  480.53024],
#         [ 922.01   ,  480.97076],
#         [1079.6804 ,  476.77158],
#         [1102.1538 ,  470.88895],
#         [1127.3098 ,  473.5421 ],
#         [1148.4727 ,  477.3492 ],
#         [1128.0559 ,  483.6303 ],
#         [1101.0978 ,  482.34576],
#         [ 951.96533,  668.1343 ],
#         [ 978.1028 ,  653.653  ],
#         [1009.08514,  641.0105 ],
#         [1025.7628 ,  643.3294 ],
#         [1041.3269 ,  640.44116],
#         [1071.0435 ,  651.32196],
#         [ 995.59357,  733.37897],
#         [ 972.77637,  716.6581 ],
#         [ 956.5391 ,  681.3474 ],
#         [1002.37476,  664.8809 ],
#         [1024.59   ,  663.96277],
#         [1045.377  ,  664.8443 ],
#         [1092.6267 ,  680.7621 ],
#         [1047.3802 ,  707.43054],
#         [1023.17444,  711.9948 ],
#         [ 999.4644 ,  708.1938 ]], dtype=float32),
#  array([[ 813.17114,  472.20123],
#         [ 815.4202 ,  528.71814],
#         [ 822.97375,  587.32416],
#         [ 834.95654,  639.78503],
#         [ 854.4422 ,  697.20355],
#         [ 884.0885 ,  744.1975 ],
#         [ 914.6941 ,  779.58826],
#         [ 957.58203,  815.52893],
#         [1024.697  ,  836.3057 ],
#         [1089.4116 ,  816.3817 ],
#         [1133.5221 ,  783.62756],
#         [1164.5134 ,  746.06055],
#         [1194.0864 ,  696.2648 ],
#         [1210.6868 ,  639.7816 ],
#         [1220.0645 ,  586.96533],
#         [1229.1124 ,  531.3447 ],
#         [1230.0276 ,  474.77765],
#         [ 860.5718 ,  428.91968],
#         [ 882.34503,  411.05048],
#         [ 912.21985,  406.70114],
#         [ 942.54443,  407.70364],
#         [ 970.1584 ,  412.58746],
#         [1076.8281 ,  412.95923],
#         [1103.8202 ,  409.04425],
#         [1133.8594 ,  408.83398],
#         [1163.7822 ,  414.16296],
#         [1189.5024 ,  433.36963],
#         [1023.3579 ,  476.9525 ],
#         [1023.69415,  512.6741 ],
#         [1022.59045,  549.1422 ],
#         [1021.5708 ,  578.30554],
#         [ 986.183  ,  604.7802 ],
#         [1003.1869 ,  606.6073 ],
#         [1023.6903 ,  609.7461 ],
#         [1043.8838 ,  606.9673 ],
#         [1059.7363 ,  604.90717],
#         [ 896.97614,  476.1181 ],
#         [ 921.0647 ,  467.2582 ],
#         [ 944.56836,  466.74075],
#         [ 967.5753 ,  477.6108 ],
#         [ 946.54285,  480.98148],
#         [ 921.51514,  481.86563],
#         [1078.322  ,  477.7131 ],
#         [1104.4313 ,  467.475  ],
#         [1131.2261 ,  469.1267 ],
#         [1151.0815 ,  477.94812],
#         [1131.1229 ,  482.0859 ],
#         [1103.4429 ,  481.80438],
#         [ 950.48474,  686.53143],
#         [ 972.7877 ,  661.75415],
#         [1007.72107,  646.02655],
#         [1024.568  ,  649.76984],
#         [1041.1232 ,  646.66754],
#         [1073.7063 ,  660.9784 ],
#         [1099.0266 ,  681.8065 ],
#         [1074.887  ,  718.0983 ],
#         [1049.6089 ,  734.69476],
#         [1023.8373 ,  738.64856],
#         [ 995.36096,  735.45856],
#         [ 972.7283 ,  719.67865],
#         [ 957.02795,  685.1231 ],
#         [1002.59814,  666.91797],
#         [1023.7398 ,  666.46136],
#         [1044.7644 ,  667.6937 ],
#         [1091.8633 ,  681.5575 ],
#         [1047.3389 ,  708.38934],
#         [1023.022  ,  715.40576],
#         [ 999.33777,  711.6589 ]], dtype=float32),
#  array([[ 813.2501 ,  471.63974],
#         [ 815.2493 ,  528.25665],
#         [ 823.2754 ,  587.6491 ],
#         [ 941.5908 ,  471.63995],
#         [ 964.1428 ,  474.2108 ],
#         [ 944.37476,  482.54312],
#         [ 919.8135 ,  483.65628],
#         [1078.3724 ,  473.40536],
#         [1101.2542 ,  472.13782],
#         [1126.4254 ,  473.28   ],
#         [1148.9604 ,  474.3346 ],
#         [1127.3042 ,  484.4664 ],
#         [1099.7668 ,  483.80682],
#         [ 949.21826,  671.9167 ],
#         [ 973.803  ,  653.98535],
#         [1006.1031 ,  639.9965 ],
#         [1023.24084,  644.0748 ],
#         [1039.4275 ,  640.2222 ],
#         [1070.0597 ,  652.5676 ],
#         [1097.61   ,  667.1085 ],
#         [1070.0812 ,  685.93463],
#         [1047.5116 ,  697.26636],
#         [1024.7793 ,  699.543  ],
#         [ 999.1997 ,  697.87866],
#         [ 976.0097 ,  689.69867],
#         [ 957.08044,  669.9096 ],
#         [1001.4773 ,  663.37213],
#         [1023.13367,  662.2233 ],
#         [1043.7241 ,  662.217  ],
#         [1089.3682 ,  666.1582 ],
#         [1045.0171 ,  672.3445 ],
#         [1023.22034,  675.9974 ],
#         [1001.6577 ,  674.60284]], dtype=float32),
#  array([[ 812.5826 ,  475.14597],
#         [ 815.1118 ,  530.4035 ],
#         [ 822.6629 ,  588.0006 ],
#         [ 833.855  ,  639.55493],
#         [ 851.5591 ,  693.1406 ],
#         [ 881.9071 ,  736.4455 ],
#         [ 915.4491 ,  767.75903],
#         [ 957.89746,  796.0871 ],
#         [1023.34705,  814.3024 ],
#         [1088.938  ,  796.41547],
#         [1132.3235 ,  770.1878 ],
#         [1166.4971 ,  739.29065],
#         [1197.5608 ,  692.62506],
#         [1212.7981 ,  635.86725],
#         [1221.0806 ,  583.849  ],
#         [1225.8007 ,  529.32074],
#         [1227.868  ,  472.96042],
#         [ 858.49316,  430.40186],
#         [ 880.2103 ,  412.646  ],
#         [ 909.2715 ,  404.78638],
#         [ 938.7105 ,  405.65826],
#         [ 966.3775 ,  411.54843],
#         [1073.7527 ,  413.34378],
#         [1100.2513 ,  405.60736],
#         [1130.313  ,  405.76962],
#         [1162.0841 ,  414.5151 ],
#         [1185.9781 ,  431.46417],
#         [1020.77515,  474.7119 ],
#         [1021.0065 ,  513.714  ],
#         [1020.0232 ,  545.56616],
#         [1019.20416,  576.37646],
#         [ 985.83936,  599.224  ],
#         [1002.02124,  602.29376],
#         [1021.2826 ,  608.82715],
#         [1042.5791 ,  601.6864 ],
#         [1057.8274 ,  598.8174 ],
#         [ 895.81665,  474.30316],
#         [ 919.30005,  471.15607],
#         [ 941.71594,  470.19568],
#         [ 964.3207 ,  474.01254],
#         [ 944.61475,  480.9045 ],
#         [ 920.4811 ,  482.558  ],
#         [1078.7422 ,  473.5009 ],
#         [1102.1019 ,  472.28937],
#         [1127.3215 ,  473.21323],
#         [1148.8307 ,  474.24796],
#         [1127.8711 ,  482.49597],
#         [1100.854  ,  481.78842],
#         [ 950.06067,  669.48236],
#         [ 975.3456 ,  654.38745],
#         [1006.7322 ,  640.6034 ],
#         [1023.65247,  644.7809 ],
#         [1086.7037 ,  662.4767 ],
#         [1043.5793 ,  666.101  ],
#         [1023.5154 ,  668.4684 ],
#         [1003.0127 ,  666.8311 ]], dtype=float32),
#  array([[ 814.2669 ,  474.91086],
#         [ 815.6399 ,  529.5383 ],
#         [ 824.6838 ,  587.3984 ],
#         [ 833.5487 ,  636.6512 ],
#         [ 851.8623 ,  688.9731 ],
#         [ 882.37695,  732.4213 ],
#         [ 915.8646 ,  764.245  ],
#         [ 957.6111 ,  792.434  ],
#         [1022.1076 ,  809.9993 ],
#         [1086.832  ,  792.81085],
#         [1131.2886 ,  765.6232 ],
#         [1166.2029 ,  735.10187],
#         [1198.0614 ,  687.75183],
#         [1213.8652 ,  631.895  ],
#         [1219.8108 ,  582.17   ],
#         [1228.1626 ,  527.92883],
#         [1229.3167 ,  471.47015],
#         [ 857.6133 ,  430.2515 ],
#         [ 881.0703 ,  413.23746],
#         [ 909.8249 ,  403.62875],
#         [ 939.0683 ,  404.74307],
#         [ 967.01917,  413.49954],
#         [1072.4727 ,  413.84738],
#         [1099.     ,  405.82452],
#         [1130.0762 ,  407.965  ],
#         [1162.0674 ,  413.97446],
#         [1186.3687 ,  431.76358],
#         [1021.2251 ,  474.85464],
#         [1021.7563 ,  512.4934 ],
#         [1019.62   ,  548.09375],
#         [1018.92944,  577.85095],
#         [ 986.44653,  600.8836 ],
#         [1001.66345,  603.96606],
#         [1021.7687 ,  606.9732 ],
#         [1042.4133 ,  603.52   ],
#         [1056.8928 ,  599.12744],
#         [ 895.7945 ,  473.21017],
#         [ 918.89105,  468.83908],
#         [ 942.14417,  469.02063],
#         [ 964.89954,  474.67435],
#         [ 944.70245,  482.15375],
#         [ 919.84717,  482.8749 ],
#         [1079.0919 ,  472.89096],
#         [1101.1909 ,  469.0645 ],
#         [1125.841  ,  470.2065 ],
#         [1147.6199 ,  474.25998],
#         [1126.6531 ,  482.45102],
#         [1099.7164 ,  481.82474],
#         [ 950.7815 ,  668.8957 ],
#         [ 976.3036 ,  654.9504 ],
#         [1006.6723 ,  643.49835],
#         [1023.5654 ,  646.15765],
#         [1039.1937 ,  641.6916 ],
#         [1069.3077 ,  650.08673],
#         [1096.1077 ,  662.09735],
#         [1068.8262 ,  676.6804 ],
#         [1046.4637 ,  686.6977 ],
#         [1024.6608 ,  687.3219 ],
#         [1000.451  ,  685.5353 ],
#         [ 978.00525,  679.2468 ],
#         [ 958.02686,  667.245  ],
#         [1003.4752 ,  660.7612 ],
#         [1023.879  ,  660.2995 ],
#         [1043.6704 ,  659.8712 ],
#         [1088.2251 ,  660.9724 ],
#         [1044.2986 ,  662.2074 ],
#         [1023.708  ,  664.1379 ],
#         [1003.4762 ,  662.7844 ]], dtype=float32)]

# %% [markdown]
# ### OOP

# %%
# %%writefile modular/detector/detector.py

"""Defines a LandmarksDetector class that uses RetinaFace to detect faces
and return the landmarks of the face with biggest bounding box from the provided video file."""

import torch
from torchvision.io import read_video

from typing import List
import numpy as np

from ibug.face_detection import RetinaFacePredictor
from ibug.face_alignment import FANPredictor

class LandmarksDetector:
    def __init__(self, device: torch.device = 'cpu'):
        self.face_detector = RetinaFacePredictor(device=device, threshold=0.8)
        self.landmark_detector = FANPredictor(device=device)

    def __call__(self, filename: str) -> List[np.ndarray]:
        frames = read_video(filename=str(filename), pts_unit='sec')[0].numpy()
        landmarks = []

        for frame in frames:
            face_boxes = self.face_detector(image=frame, rgb=False)
            face_points, _ = self.landmark_detector(image=frame, face_boxes=face_boxes)

            if len(face_boxes) == 0:
                landmarks.append(None)
            else:
                # Find the largest face box
                get_size = lambda box: box[2]-box[0] + box[3]-box[1]
                max_idx, max_face_box = max(enumerate(face_boxes), key=lambda x: get_size(x[1]))

                landmarks.append(face_points[max_idx])

        return landmarks

# %%
test_detector = LandmarksDetector()
test = test_detector(sample_path)

# %%
test[0].shape
# Out:
# (68, 2)

# %% [markdown]
# ### Testing

# %%
# %%time

from modular.detector.detector import LandmarksDetector

detector_test = LandmarksDetector(device=device)
# Out:
# CPU times: user 1.7 s, sys: 22.8 ms, total: 1.73 s
# Wall time: 1.8 s

# %%
# %%time 
detector_test("data/lipread_mp4/ABOUT/train/ABOUT_00002.mp4")
# Out:
# CPU times: user 6.62 s, sys: 0 ns, total: 6.62 s
# Wall time: 4.84 s
# ([array([[ 67.91319 ,  61.646782],
#          [ 65.22506 ,  78.83026 ],
#          [ 62.706955,  96.32483 ],
#          [ 62.86235 , 114.12953 ],
#          [ 65.936485, 134.61661 ],
#          [ 74.35432 , 154.22052 ],
#          [ 83.86355 , 171.72575 ],
#          [ 97.11017 , 186.50189 ],
#          [118.2975  , 198.2279  ],
#          [139.60226 , 193.88422 ],
#          [153.94612 , 182.36923 ],
#          [165.73679 , 170.34741 ],
#          [178.41104 , 154.3452  ],
#          [186.86954 , 137.20947 ],
#          [191.99995 , 123.08406 ],
#          [197.22685 , 106.91359 ],
#          [200.80284 ,  89.37492 ],
#          [ 87.48561 ,  69.58456 ],
#          [ 97.267456,  69.89199 ],
#          [107.27069 ,  72.27311 ],
#          [115.90975 ,  76.99359 ],
#          [123.43692 ,  81.66051 ],
#          [155.47221 ,  85.34875 ],
#          [163.44937 ,  82.65265 ],
#          [172.91571 ,  80.7842  ],
#          [182.32715 ,  79.898705],
#          [189.96754 ,  82.75546 ],
#          [137.53133 , 100.222015],
#          [135.58752 , 113.253296],
#          [133.75261 , 125.99963 ],
#          [132.00487 , 136.31148 ],
#          [119.48386 , 134.86638 ],
#          [123.88861 , 137.87117 ],
#          [130.22156 , 141.13335 ],
#          [136.74767 , 140.60414 ],
#          [141.62424 , 138.63036 ],
#          [ 97.33055 ,  86.89949 ],
#          [105.173485,  88.40659 ],
#          [112.77785 ,  89.77819 ],
#          [119.90791 ,  92.005295],
#          [112.787964,  93.36217 ],
#          [104.381454,  91.834656],
#          [153.24103 ,  96.28281 ],
#          [160.97148 ,  95.758575],
#          [169.34224 ,  96.499435],
#          [176.02998 ,  96.85666 ],
#          [169.09756 , 100.59073 ],
#          [160.15155 , 100.19614 ],
#          [134.19778 , 155.25967 ],
#          [148.52274 , 155.59782 ],
#          [133.99525 , 159.55989 ],
#          [126.80667 , 159.69391 ],
#          [120.166275, 157.37328 ]], dtype=float32),
#   array([[ 66.66894 ,  60.887062],
#          [ 63.433296,  78.07145 ],
#          [ 61.17385 ,  95.96269 ],
#          [ 61.223007, 113.101166],
#          [ 65.06149 , 134.33487 ],
#          [ 73.422134, 154.34773 ],
#          [ 83.04533 , 172.28038 ],
#          [ 96.13434 , 187.3864  ],
#          [117.1035  , 198.64836 ],
#          [139.00021 , 193.94073 ],
#          [153.43594 , 181.68523 ],
#          [164.8092  , 169.01631 ],
#          [177.52666 , 153.09705 ],
#          [186.09177 , 135.97386 ],
#          [191.29485 , 121.74353 ],
#          [196.27605 , 105.797134],
#          [199.97787 ,  87.79171 ],
#          [ 86.86665 ,  69.18891 ],
#          [ 96.781525,  69.830025],
#          [106.88501 ,  71.737625],
#          [116.03176 ,  75.99334 ],
#          [123.41443 ,  80.76861 ],
#          [155.33505 ,  84.60979 ],
#          [163.39839 ,  82.49348 ],
#          [172.84085 ,  80.28207 ],
#          [182.43382 ,  79.42126 ],
#          [189.78633 ,  81.77035 ],
#          [137.41197 ,  99.28871 ],
#          [135.7415  , 112.57344 ],
#          [133.84506 , 125.732254],
#          [132.09596 , 135.96964 ],
#          [119.03093 , 134.75717 ],
#          [123.54518 , 137.9304  ],
#          [130.02716 , 141.19527 ],
#          [136.56781 , 139.89308 ],
#          [141.24338 , 137.78801 ],
#          [ 96.37268 ,  86.50377 ],
#          [104.66223 ,  87.756874],
#          [112.24479 ,  88.91274 ],
#          [119.520615,  92.11688 ],
#          [112.25459 ,  92.84235 ],
#          [103.893394,  91.61813 ],
#          [152.9156  ,  96.16377 ],
#          [160.65752 ,  95.20593 ],
#          [169.06769 ,  96.3239  ],
#          [175.92517 ,  96.51337 ],
#          [168.60773 ,  99.49228 ],
#          [159.72621 ,  99.1687  ],
#          [102.13399 , 147.8524  ],
#          [111.667244, 148.0818  ],
#          [123.370605, 149.54364 ],
#          [128.50368 , 151.7518  ],
#          [133.50421 , 151.2071  ],
#          [142.64664 , 153.5193  ],
#          [150.43288 , 155.87627 ],
#          [140.79118 , 165.09735 ],
#          [132.35744 , 169.58943 ],
#          [124.62338 , 169.39368 ],
#          [116.592186, 166.76875 ],
#          [109.78778 , 160.25197 ],
#          [104.35092 , 148.66405 ],
#          [120.1978  , 153.44464 ],
#          [127.125626, 155.04745 ],
#          [133.56415 , 155.65686 ],
#          [147.70883 , 155.85104 ],
#          [133.20886 , 160.71124 ],
#          [125.83176 , 161.16467 ],
#          [118.91644 , 158.90001 ]], dtype=float32),
#   array([[ 67.465515,  59.447815],
#          [ 64.612015,  76.337975],
#          [ 61.228043,  94.674736],
#          [ 61.09942 , 111.7462  ],
#          [ 64.44433 , 133.02283 ],
#          [ 72.591354, 152.60739 ],
#          [ 81.74858 , 170.76215 ],
#          [ 94.73782 , 187.05911 ],
#          [116.26903 , 198.92201 ],
#          [138.10844 , 193.9487  ],
#          [152.62216 , 180.96115 ],
#          [164.22816 , 168.45117 ],
#          [177.26794 , 151.99094 ],
#          [185.86655 , 134.29477 ],
#          [191.0707  , 119.39693 ],
#          [196.15923 , 103.45456 ],
#          [199.8133  ,  85.46292 ],
#          [ 87.84144 ,  69.01524 ],
#          [ 97.69969 ,  69.43835 ],
#          [108.07273 ,  72.26438 ],
#          [116.955315,  76.72685 ],
#          [124.249435,  81.28063 ],
#          [155.6474  ,  84.872734],
#          [163.23338 ,  82.11121 ],
#          [172.74713 ,  80.31361 ],
#          [182.26355 ,  79.0048  ],
#          [189.6445  ,  80.76802 ],
#          [137.44063 ,  99.54254 ],
#          [136.04227 , 112.95401 ],
#          [134.4113  , 126.3665  ],
#          [132.61076 , 136.25914 ],
#          [119.39499 , 134.64682 ],
#          [123.987625, 137.88414 ],
#          [130.26976 , 140.16669 ],
#          [136.96321 , 138.97144 ],
#          [141.67638 , 137.49083 ],
#          [ 97.18003 ,  86.00579 ],
#          [105.335724,  88.00297 ],
#          [112.9755  ,  89.15194 ],
#          [120.05821 ,  90.78341 ],
#          [112.999054,  92.20571 ],
#          [104.58928 ,  90.797935],
#          [153.10612 ,  95.22781 ],
#          [160.81328 ,  94.32786 ],
#          [169.11604 ,  95.385345],
#          [175.95222 ,  95.50746 ],
#          [168.84558 ,  99.43175 ],
#          [159.84315 ,  99.070526],
#          [100.99558 , 146.75761 ],
#          [111.082344, 147.79247 ],
#          [123.052765, 149.38214 ],
#          [128.60027 , 152.05316 ],
#          [133.8286  , 151.60625 ],
#          [143.29822 , 152.79285 ],
#          [150.95378 , 153.41379 ],
#          [140.81792 , 164.71034 ],
#          [132.19664 , 169.86967 ],
#          [124.33583 , 169.53003 ],
#          [115.89462 , 166.16518 ],
#          [108.66751 , 159.36285 ],
#          [102.844215, 147.27426 ],
#          [120.10131 , 152.81294 ],
#          [127.17656 , 155.03833 ],
#          [133.91322 , 155.54654 ],
#          [148.26    , 153.65036 ],
#          [133.14983 , 161.0363  ],
#          [125.52045 , 161.45808 ],
#          [118.496605, 158.73744 ]], dtype=float32),
#   array([[ 66.82612 ,  59.08374 ],
#          [ 63.09722 ,  76.16611 ],
#          [ 60.129448,  94.9422  ],
#          [ 59.82241 , 112.15402 ],
#          [ 63.588806, 133.88362 ],
#          [ 71.59574 , 153.89029 ],
#          [ 81.17968 , 171.99457 ],
#          [ 94.72604 , 187.68692 ],
#          [116.019684, 198.33273 ],
#          [137.6471  , 193.83163 ],
#          [151.96735 , 182.33829 ],
#          [164.12715 , 170.4431  ],
#          [177.05368 , 154.33878 ],
#          [185.674   , 136.97224 ],
#          [190.69144 , 122.47133 ],
#          [195.48796 , 106.45131 ],
#          [199.24788 ,  88.468636],
#          [ 87.66391 ,  69.6414  ],
#          [ 98.06134 ,  70.61801 ],
#          [108.4795  ,  72.37398 ],
#          [117.72637 ,  76.87283 ],
#          [125.250046,  81.62161 ],
#          [157.05244 ,  85.14106 ],
#          [165.18416 ,  83.058655],
#          [174.65881 ,  80.66376 ],
#          [184.11858 ,  79.60193 ],
#          [190.79948 ,  81.99867 ],
#          [139.2511  , 100.21019 ],
#          [137.1189  , 113.74669 ],
#          [135.69756 , 126.872635],
#          [133.62697 , 137.0377  ],
#          [119.569305, 134.90933 ],
#          [124.00874 , 138.0402  ],
#          [130.90414 , 141.49188 ],
#          [137.36118 , 140.60136 ],
#          [142.249   , 137.96751 ],
#          [ 97.829895,  87.308975],
#          [105.78535 ,  88.484604],
#          [113.65814 ,  89.530075],
#          [121.001465,  92.44465 ],
#          [113.62111 ,  93.157616],
#          [105.088615,  92.1094  ],
#          [154.0673  ,  96.319016],
#          [161.81923 ,  95.78995 ],
#          [170.07387 ,  96.687775],
#          [176.77399 ,  96.60805 ],
#          [169.53851 ,  99.65367 ],
#          [160.94064 ,  99.51123 ],
#          [100.989746, 146.26085 ],
#          [111.08685 , 147.3997  ],
#          [123.45624 , 149.473   ],
#          [128.9334  , 151.66661 ],
#          [134.15154 , 151.06563 ],
#          [143.43784 , 152.8859  ],
#          [150.86423 , 154.9317  ],
#          [140.79282 , 164.40283 ],
#          [132.39754 , 169.03658 ],
#          [124.62337 , 168.79453 ],
#          [116.15242 , 165.73625 ],
#          [108.7816  , 159.13304 ],
#          [102.959816, 146.72415 ],
#          [120.09929 , 152.7523  ],
#          [127.449585, 154.65256 ],
#          [133.94098 , 155.1357  ],
#          [148.25017 , 155.02385 ],
#          [133.31242 , 160.36795 ],
#          [125.8195  , 160.94566 ],
#          [118.56146 , 158.47113 ]], dtype=float32),
#   array([[ 64.15972 ,  61.033745],
#          [ 60.234016,  77.596985],
#          [ 57.96534 ,  95.86101 ],
#          [ 57.251015, 112.40079 ],
#          [ 60.600876, 134.41605 ],
#          [ 68.61857 , 155.23608 ],
#          [ 79.12123 , 173.29391 ],
#          [ 93.67136 , 188.5678  ],
#          [115.32979 , 199.634   ],
#          [136.91852 , 195.1077  ],
#          [150.51439 , 184.05704 ],
#          [162.58392 , 172.48145 ],
#          [175.662   , 156.22913 ],
#          [183.93423 , 139.12387 ],
#          [188.88431 , 124.796906],
#          [193.58858 , 108.750916],
#          [196.95819 ,  91.26359 ],
#          [ 86.720314,  71.08235 ],
#          [ 97.73187 ,  71.75795 ],
#          [108.305534,  74.35855 ],
#          [117.409424,  78.67237 ],
#          [125.01111 ,  83.11257 ],
#          [157.22272 ,  87.06482 ],
#          [165.06197 ,  84.36568 ],
#          [174.12779 ,  81.74855 ],
#          [183.00594 ,  80.72024 ],
#          [189.44724 ,  83.257614],
#          [138.55853 , 101.53639 ],
#          [137.45842 , 114.80556 ],
#          [136.1332  , 128.17087 ],
#          [133.63023 , 138.14842 ],
#          [118.88806 , 136.13351 ],
#          [123.86565 , 139.15157 ],
#          [130.48975 , 142.58235 ],
#          [137.07645 , 141.92854 ],
#          [142.25102 , 139.36237 ],
#          [ 97.42841 ,  88.52494 ],
#          [105.167015,  90.00987 ],
#          [112.92699 ,  91.28067 ],
#          [120.21448 ,  93.491165],
#          [112.895386,  94.75076 ],
#          [104.352   ,  93.305954],
#          [153.5479  ,  97.61124 ],
#          [161.30432 ,  97.04903 ],
#          [169.61029 ,  97.64026 ],
#          [175.84065 ,  97.73003 ],
#          [169.1014  , 101.41824 ],
#          [160.55675 , 101.28804 ],
#          [ 99.40538 , 147.1456  ],
#          [110.4072  , 148.41653 ],
#          [122.62785 , 150.5212  ],
#          [128.19247 , 152.84853 ],
#          [133.85968 , 152.20972 ],
#          [143.29768 , 153.95447 ],
#          [150.69966 , 155.78127 ],
#          [140.4214  , 164.9403  ],
#          [131.97392 , 169.67337 ],
#          [124.031586, 169.3656  ],
#          [115.55491 , 166.20496 ],
#          [108.03844 , 159.71837 ],
#          [101.53941 , 147.568   ],
#          [119.472046, 153.88593 ],
#          [126.73915 , 155.75711 ],
#          [133.84311 , 156.15933 ],
#          [148.09802 , 155.86801 ],
#          [133.14558 , 161.12228 ],
#          [125.17038 , 161.63882 ],
#          [117.9259  , 159.19038 ]], dtype=float32),
#   array([[ 64.206314,  60.51989 ],
#          [ 60.16919 ,  77.30944 ],
#          [ 57.255714,  95.73102 ],
#          [ 56.75747 , 112.70912 ],
#          [ 60.31102 , 134.89705 ],
#          [ 68.35497 , 155.54564 ],
#          [ 79.14803 , 173.4234  ],
#          [ 93.628365, 188.63911 ],
#          [114.959175, 199.54305 ],
#          [136.46431 , 195.04192 ],
#          [150.11993 , 184.03831 ],
#          [161.87257 , 172.52242 ],
#          [174.84528 , 156.43398 ],
#          [183.3277  , 138.9166  ],
#          [188.53758 , 124.30319 ],
#          [193.46346 , 108.06067 ],
#          [196.53305 ,  91.20468 ],
#          [ 87.64087 ,  71.39687 ],
#          [ 98.59796 ,  72.11625 ],
#          [109.07118 ,  74.712   ],
#          [118.18767 ,  79.25967 ],
#          [125.77971 ,  83.58504 ],
#          [157.65837 ,  87.49423 ],
#          [165.4936  ,  84.945496],
#          [174.47365 ,  82.27426 ],
#          [183.22893 ,  81.0574  ],
#          [189.55199 ,  83.44975 ],
#          [139.21904 , 101.916855],
#          [138.18968 , 115.240616],
#          [137.19601 , 128.68489 ],
#          [134.68709 , 138.58078 ],
#          [119.47772 , 136.38727 ],
#          [124.47653 , 139.4811  ],
#          [131.08897 , 142.9042  ],
#          [137.60104 , 142.25253 ],
#          [142.65501 , 139.57965 ],
#          [ 98.02647 ,  88.87145 ],
#          [105.68557 ,  90.22174 ],
#          [113.38801 ,  91.52024 ],
#          [120.62071 ,  93.86195 ],
#          [113.36776 ,  95.06224 ],
#          [104.82813 ,  93.69465 ],
#          [153.9354  ,  97.792694],
#          [161.62587 ,  97.34509 ],
#          [169.97005 ,  97.96155 ],
#          [176.23495 ,  97.833176],
#          [169.37523 , 101.20924 ],
#          [160.9688  , 101.12239 ],
#          [ 99.90957 , 147.56653 ],
#          [111.05545 , 148.76694 ],
#          [123.27609 , 150.74579 ],
#          [128.78513 , 153.04076 ],
#          [134.45143 , 152.42883 ],
#          [143.49602 , 154.10733 ],
#          [150.68646 , 155.94432 ],
#          [140.65675 , 165.01952 ],
#          [132.51126 , 169.77478 ],
#          [124.64171 , 169.38899 ],
#          [116.2772  , 166.17853 ],
#          [108.66487 , 159.89816 ],
#          [102.11708 , 147.991   ],
#          [120.02411 , 154.11848 ],
#          [127.27855 , 155.97183 ],
#          [134.24634 , 156.35417 ],
#          [148.05367 , 156.01767 ],
#          [133.57066 , 161.28197 ],
#          [125.749405, 161.7264  ],
#          [118.58165 , 159.2714  ]], dtype=float32),
#   array([[ 64.11588 ,  58.333397],
#          [ 59.664192,  75.66876 ],
#          [ 56.843765,  94.59776 ],
#          [ 56.295662, 111.65837 ],
#          [ 60.063377, 134.3243  ],
#          [ 68.05852 , 154.59882 ],
#          [ 79.289925, 172.45155 ],
#          [ 93.85328 , 187.56914 ],
#          [115.69109 , 198.36575 ],
#          [137.0268  , 193.6447  ],
#          [150.82008 , 182.58868 ],
#          [162.9581  , 170.47978 ],
#          [176.17848 , 153.75198 ],
#          [184.0235  , 136.59995 ],
#          [188.9299  , 122.40161 ],
#          [194.03314 , 106.81563 ],
#          [196.9096  ,  89.74772 ],
#          [ 87.975876,  70.65547 ],
#          [ 98.66902 ,  71.01153 ],
#          [109.438934,  73.35244 ],
#          [118.68325 ,  78.0711  ],
#          [126.05951 ,  82.5856  ],
#          [158.37277 ,  86.297035],
#          [166.36507 ,  83.8342  ],
#          [175.37144 ,  81.646385],
#          [183.91501 ,  80.63694 ],
#          [189.8355  ,  81.982254],
#          [139.62984 , 101.050446],
#          [137.93298 , 114.65256 ],
#          [136.92442 , 128.0772  ],
#          [134.29295 , 138.03879 ],
#          [120.09416 , 135.55225 ],
#          [124.57439 , 138.78117 ],
#          [131.2079  , 142.19174 ],
#          [137.79745 , 141.5664  ],
#          [142.46689 , 138.87045 ],
#          [ 98.02521 ,  88.33035 ],
#          [106.13862 ,  89.416275],
#          [113.68714 ,  90.38961 ],
#          [121.10672 ,  93.45437 ],
#          [113.61831 ,  94.09032 ],
#          [105.31322 ,  93.22673 ],
#          [154.3042  ,  97.29393 ],
#          [162.17111 ,  96.55429 ],
#          [170.04948 ,  97.339264],
#          [176.55876 ,  96.71387 ],
#          [169.7038  , 100.208954],
#          [161.17087 , 100.164154],
#          [100.21604 , 146.80835 ],
#          [111.33326 , 148.38678 ],
#          [123.59407 , 150.37393 ],
#          [128.84363 , 152.66182 ],
#          [134.00899 , 152.11008 ],
#          [143.10478 , 154.32892 ],
#          [150.47028 , 155.3277  ],
#          [140.88791 , 164.0783  ],
#          [132.55229 , 168.79076 ],
#          [124.74823 , 168.60898 ],
#          [116.41357 , 165.85818 ],
#          [108.97218 , 159.44543 ],
#          [102.35519 , 147.30232 ],
#          [120.378006, 153.89484 ],
#          [127.310104, 155.53105 ],
#          [133.96494 , 156.07243 ],
#          [147.93846 , 155.38269 ],
#          [133.59549 , 160.15312 ],
#          [126.002945, 160.76628 ],
#          [118.87141 , 158.54463 ]], dtype=float32),
#   array([[ 63.87413 ,  58.867416],
#          [ 59.359123,  75.84378 ],
#          [ 57.544273,  94.45384 ],
#          [ 57.429314, 111.0686  ],
#          [ 60.14856 , 133.28185 ],
#          [ 67.51727 , 153.57475 ],
#          [ 77.97833 , 172.17284 ],
#          [ 92.14339 , 188.24478 ],
#          [114.132744, 199.18039 ],
#          [135.68698 , 194.35588 ],
#          [149.10135 , 182.93018 ],
#          [160.7914  , 170.51578 ],
#          [173.74632 , 153.62184 ],
#          [181.89984 , 136.1339  ],
#          [187.12808 , 121.73543 ],
#          [192.22127 , 106.1042  ],
#          [195.62756 ,  89.21578 ],
#          [ 87.77683 ,  69.706856],
#          [ 98.59684 ,  69.919395],
#          [109.140114,  72.5233  ],
#          [118.451035,  77.19708 ],
#          [125.691315,  81.7322  ],
#          [157.887   ,  85.89443 ],
#          [165.91183 ,  83.66037 ],
#          [174.81407 ,  81.387924],
#          [183.56215 ,  80.24982 ],
#          [189.53665 ,  81.72284 ],
#          [139.0238  , 100.3925  ],
#          [137.61938 , 113.85103 ],
#          [136.39621 , 127.3416  ],
#          [133.72163 , 137.50972 ],
#          [118.49619 , 134.8774  ],
#          [123.776825, 138.18214 ],
#          [130.4582  , 141.59335 ],
#          [136.90213 , 140.92287 ],
#          [141.82562 , 138.4156  ],
#          [ 97.81718 ,  87.54774 ],
#          [105.62376 ,  88.79453 ],
#          [113.254135,  89.62174 ],
#          [120.65727 ,  92.87724 ],
#          [113.16012 ,  93.59406 ],
#          [104.66037 ,  92.5528  ],
#          [153.76437 ,  96.95115 ],
#          [161.40767 ,  96.454216],
#          [169.69455 ,  97.32599 ],
#          [175.78633 ,  96.701775],
#          [169.12811 ,  99.9946  ],
#          [160.56694 ,  99.97696 ],
#          [ 99.414276, 146.616   ],
#          [110.0362  , 148.06017 ],
#          [122.54471 , 150.17041 ],
#          [128.09572 , 152.88742 ],
#          [133.54572 , 152.39127 ],
#          [142.49913 , 154.29837 ],
#          [149.64296 , 155.013   ],
#          [140.16708 , 165.4879  ],
#          [131.69707 , 170.48445 ],
#          [123.70192 , 170.04628 ],
#          [115.08952 , 166.8303  ],
#          [107.84705 , 159.9247  ],
#          [101.50294 , 147.2839  ],
#          [119.366295, 153.72581 ],
#          [126.601715, 155.76196 ],
#          [133.48717 , 156.33585 ],
#          [147.07852 , 155.0801  ],
#          [132.74878 , 161.8298  ],
#          [124.864426, 162.39177 ],
#          [117.66326 , 159.38234 ]], dtype=float32),
#   array([[ 64.495964,  55.90113 ],
#          [ 59.793045,  73.44379 ],
#          [ 57.66632 ,  92.629135],
#          [ 57.562737, 109.61693 ],
#          [ 60.16179 , 131.83647 ],
#          [ 67.47485 , 152.64331 ],
#          [ 77.83216 , 171.15573 ],
#          [ 92.28239 , 187.15193 ],
#          [113.83165 , 198.21552 ],
#          [135.14967 , 193.6406  ],
#          [148.44894 , 182.31308 ],
#          [160.03302 , 169.90726 ],
#          [172.9672  , 153.25267 ],
#          [181.45116 , 135.89809 ],
#          [187.04196 , 121.749466],
#          [192.4339  , 106.39249 ],
#          [196.3536  ,  89.71504 ],
#          [ 89.358536,  67.74106 ],
#          [100.1572  ,  68.14872 ],
#          [110.900536,  71.101974],
#          [119.978714,  75.68793 ],
#          [127.26262 ,  80.506996],
#          [159.45287 ,  85.152695],
#          [167.46739 ,  83.01668 ],
#          [176.44566 ,  80.64913 ],
#          [184.90652 ,  79.5861  ],
#          [190.57051 ,  81.6077  ],
#          [140.0336  ,  99.45296 ],
#          [138.20189 , 113.03754 ],
#          [137.09598 , 126.43326 ],
#          [134.38232 , 136.49957 ],
#          [119.01278 , 134.03784 ],
#          [124.27603 , 137.29085 ],
#          [130.89383 , 140.64716 ],
#          [137.42387 , 140.10358 ],
#          [142.24254 , 137.72542 ],
#          [ 98.654755,  85.84976 ],
#          [106.96912 ,  87.494095],
#          [114.56897 ,  88.52885 ],
#          [121.68936 ,  91.83168 ],
#          [114.18368 ,  92.452675],
#          [105.907845,  91.150894],
#          [154.67426 ,  95.93025 ],
#          [162.5199  ,  95.21879 ],
#          [170.54315 ,  96.362625],
#          [176.81438 ,  96.08002 ],
#          [169.91685 ,  99.42554 ],
#          [161.24948 ,  99.28885 ],
#          [ 99.93996 , 146.10191 ],
#          [110.751366, 147.42868 ],
#          [123.05948 , 149.33142 ],
#          [128.49416 , 151.99072 ],
#          [133.79053 , 151.49228 ],
#          [142.5562  , 153.48732 ],
#          [149.15253 , 154.34299 ],
#          [140.27359 , 165.40518 ],
#          [131.81993 , 170.66129 ],
#          [123.814255, 170.0288  ],
#          [115.179756, 166.6491  ],
#          [108.138275, 159.63217 ],
#          [102.048584, 146.83722 ],
#          [119.94843 , 153.06346 ],
#          [127.02731 , 154.97968 ],
#          [133.80518 , 155.58589 ],
#          [146.82576 , 154.46338 ],
#          [132.90663 , 161.8015  ],
#          [125.08026 , 162.25334 ],
#          [117.95469 , 159.09671 ]], dtype=float32),
#   array([[ 65.24867 ,  57.92431 ],
#          [ 60.175995,  75.17382 ],
#          [ 58.154594,  94.147675],
#          [ 57.842583, 110.76926 ],
#          [ 60.193817, 132.86218 ],
#          [ 67.06978 , 153.28024 ],
#          [ 76.82507 , 172.18085 ],
#          [ 90.47179 , 187.9864  ],
#          [111.73881 , 199.08342 ],
#          [133.93655 , 195.22705 ],
#          [147.34732 , 184.79994 ],
#          [157.92387 , 173.76764 ],
#          [170.33089 , 157.57687 ],
#          [179.21895 , 139.78387 ],
#          [185.56944 , 125.92877 ],
#          [191.70396 , 110.54257 ],
#          [195.69525 ,  93.93937 ],
#          [ 90.294   ,  69.33111 ],
#          [100.9995  ,  69.42705 ],
#          [111.542244,  72.18914 ],
#          [120.62249 ,  76.869446],
#          [127.90759 ,  81.50697 ],
#          [159.69313 ,  86.78084 ],
#          [167.77559 ,  84.42456 ],
#          [176.54842 ,  82.42478 ],
#          [185.07425 ,  81.7934  ],
#          [190.67416 ,  84.4313  ],
#          [140.3969  , 100.59369 ],
#          [138.4922  , 113.72511 ],
#          [136.36732 , 126.79152 ],
#          [133.95241 , 137.06248 ],
#          [119.01978 , 135.70898 ],
#          [116.31502 , 155.40692 ],
#          [127.36798 , 158.30968 ],
#          [138.50172 , 159.95363 ],
#          [143.43996 , 162.73618 ],
#          [148.3694  , 162.59148 ],
#          [156.5521  , 163.90692 ],
#          [163.89522 , 164.64641 ],
#          [154.41592 , 170.62868 ],
#          [147.2205  , 173.00352 ],
#          [140.58281 , 172.35782 ],
#          [133.24457 , 170.0505  ],
#          [125.94353 , 164.79396 ],
#          [118.2505  , 156.11424 ],
#          [135.34586 , 163.10881 ],
#          [142.23087 , 165.2356  ],
#          [148.15312 , 165.93504 ],
#          [161.32983 , 164.4346  ],
#          [148.16283 , 166.4629  ],
#          [141.7979  , 166.30696 ],
#          [135.34213 , 163.81717 ]], dtype=float32),
#   array([[ 69.439964,  57.37581 ],
#          [ 64.001114,  74.54345 ],
#          [ 61.064606,  93.926254],
#          [ 60.72319 , 110.995575],
#          [ 63.280838, 134.23901 ],
#          [ 70.26078 , 154.91739 ],
#          [ 81.010315, 171.79091 ],
#          [ 94.84215 , 186.62123 ],
#          [114.404564, 196.99614 ],
#          [135.74176 , 194.35936 ],
#          [148.0766  , 185.12387 ],
#          [159.30435 , 175.23871 ],
#          [172.18788 , 160.70052 ],
#          [181.59744 , 143.95195 ],
#          [188.58133 , 130.42993 ],
#          [195.02608 , 115.07143 ],
#          [199.67494 ,  97.95514 ],
#          [ 94.665825,  70.20762 ],
#          [105.608536,  70.804504],
#          [116.51212 ,  73.63174 ],
#          [125.42084 ,  78.49601 ],
#          [132.64241 ,  83.38306 ],
#          [163.88751 ,  90.666084],
#          [171.7968  ,  88.55788 ],
#          [180.89511 ,  87.11435 ],
#          [189.6056  ,  86.68837 ],
#          [195.2031  ,  88.660675],
#          [144.38425 , 102.88228 ],
#          [141.88828 , 116.08043 ],
#          [139.60657 , 128.87889 ],
#          [137.12782 , 138.69037 ],
#          [122.63931 , 137.75299 ],
#          [127.27768 , 141.16354 ],
#          [133.27827 , 144.15817 ],
#          [139.48431 , 143.0504  ],
#          [143.9594  , 141.80284 ],
#          [104.16191 ,  88.13596 ],
#          [112.0226  ,  90.18676 ],
#          [119.75795 ,  91.65988 ],
#          [126.237595,  94.47725 ],
#          [119.25899 ,  95.16992 ],
#          [111.12431 ,  93.14476 ],
#          [158.58398 , 101.15784 ],
#          [166.30304 , 100.42789 ],
#          [174.42653 , 101.72087 ],
#          [179.7477  , 102.127975],
#          [173.53905 , 105.98216 ],
#          [165.05795 , 104.968124],
#          [103.230125, 150.13165 ],
#          [113.94333 , 151.24605 ],
#          [125.16751 , 153.17065 ],
#          [129.76808 , 155.83109 ],
#          [134.88986 , 155.69513 ],
#          [142.88745 , 158.26448 ],
#          [149.76808 , 159.49112 ],
#          [140.05331 , 164.76353 ],
#          [133.11671 , 168.00572 ],
#          [126.310745, 167.26291 ],
#          [119.15763 , 164.2219  ],
#          [112.42045 , 159.05441 ],
#          [105.18735 , 150.49728 ],
#          [121.75286 , 156.40677 ],
#          [128.44241 , 158.75752 ],
#          [134.54912 , 159.4688  ],
#          [147.20259 , 159.14578 ],
#          [134.3517  , 160.36282 ],
#          [127.5495  , 160.19707 ],
#          [121.43468 , 158.0465  ]], dtype=float32),
#   array([[ 70.28042 ,  50.470497],
#          [ 63.90725 ,  68.44206 ],
#          [ 60.252975,  87.67985 ],
#          [ 59.500893, 104.61572 ],
#          [ 60.498535, 127.75548 ],
#          [ 66.38936 , 150.02559 ],
#          [ 75.8379  , 169.4745  ],
#          [ 89.96761 , 185.85867 ],
#          [110.02191 , 196.8826  ],
#          [131.96712 , 194.07388 ],
#          [144.37634 , 183.97539 ],
#          [156.6047  , 173.33176 ],
#          [169.97192 , 158.48744 ],
#          [180.26064 , 141.43076 ],
#          [187.63622 , 127.35625 ],
#          [194.47644 , 111.76375 ],
#          [199.2019  ,  95.271225],
#          [ 94.88842 ,  65.53779 ],
#          [105.71473 ,  66.332535],
#          [116.391106,  69.40413 ],
#          [125.28105 ,  73.95246 ],
#          [132.34915 ,  79.12892 ],
#          [164.06487 ,  86.74356 ],
#          [171.91193 ,  84.42663 ],
#          [180.68114 ,  83.421585],
#          [189.02159 ,  83.59445 ],
#          [194.37213 ,  86.16075 ],
#          [144.08905 ,  99.29036 ],
#          [141.47687 , 112.24336 ],
#          [139.14334 , 125.289856],
#          [136.24072 , 135.6536  ],
#          [121.47446 , 133.5119  ],
#          [125.74408 , 136.9196  ],
#          [131.82043 , 140.60258 ],
#          [138.3598  , 140.16011 ],
#          [142.98064 , 138.41646 ],
#          [103.385124,  83.484566],
#          [111.69893 ,  85.99155 ],
#          [119.50295 ,  87.34988 ],
#          [126.08067 ,  90.701614],
#          [118.845215,  91.103096],
#          [110.565414,  89.006424],
#          [158.79741 ,  96.85158 ],
#          [166.34784 ,  96.144226],
#          [174.17378 ,  97.512665],
#          [179.76056 ,  98.61606 ],
#          [172.92253 , 101.70682 ],
#          [165.13585 , 100.87196 ],
#          [ 99.99267 , 145.69733 ],
#          [111.34478 , 146.96138 ],
#          [122.997574, 148.41513 ],
#          [127.93654 , 151.30911 ],
#          [132.97803 , 151.45187 ],
#          [141.00156 , 154.66035 ],
#          [147.54155 , 156.0626  ],
#          [137.60344 , 164.45955 ],
#          [129.8122  , 168.68805 ],
#          [122.6949  , 167.69023 ],
#          [115.20656 , 163.92192 ],
#          [108.67308 , 157.28845 ],
#          [102.13874 , 146.2573  ],
#          [119.467   , 151.98697 ],
#          [126.3862  , 154.0778  ],
#          [132.38388 , 155.2506  ],
#          [144.95781 , 155.80722 ],
#          [131.35149 , 160.27821 ],
#          [124.33969 , 159.9675  ],
#          [117.95335 , 157.07996 ]], dtype=float32),
#   array([[ 73.833084,  50.599686],
#          [ 67.1477  ,  67.57801 ],
#          [ 62.806946,  86.45879 ],
#          [ 61.316216, 103.1767  ],
#          [ 61.835243, 126.05322 ],
#          [ 66.65957 , 148.5049  ],
#          [ 75.39964 , 167.3867  ],
#          [ 89.1203  , 184.922   ],
#          [108.89071 , 197.16698 ],
#          [130.42365 , 194.90094 ],
#          [143.35068 , 185.07796 ],
#          [155.88089 , 174.82478 ],
#          [170.42218 , 159.86389 ],
#          [181.15073 , 142.90125 ],
#          [189.06523 , 128.8338  ],
#          [196.41322 , 113.10129 ],
#          [201.53844 ,  96.3073  ],
#          [ 97.70449 ,  65.32733 ],
#          [108.78817 ,  66.59181 ],
#          [119.36728 ,  69.29801 ],
#          [128.09708 ,  74.387024],
#          [135.18051 ,  79.3929  ],
#          [166.62216 ,  87.32574 ],
#          [174.70985 ,  85.20144 ],
#          [183.55377 ,  84.39829 ],
#          [191.90236 ,  84.82936 ],
#          [197.26614 ,  87.40947 ],
#          [146.25763 ,  99.715866],
#          [143.41374 , 112.4803  ],
#          [140.95206 , 125.813385],
#          [137.69597 , 135.90324 ],
#          [122.682106, 133.04544 ],
#          [127.1805  , 136.90204 ],
#          [133.07187 , 140.66951 ],
#          [139.42624 , 140.33546 ],
#          [144.02818 , 138.86351 ],
#          [106.24887 ,  83.65357 ],
#          [114.19325 ,  85.61623 ],
#          [121.96668 ,  87.468994],
#          [128.2696  ,  90.5945  ],
#          [121.262276,  90.982056],
#          [112.96827 ,  89.03135 ],
#          [160.92952 ,  97.7796  ],
#          [168.60262 ,  97.0811  ],
#          [176.6995  ,  98.56712 ],
#          [182.17041 ,  99.64398 ],
#          [175.5118  , 102.925476],
#          [167.23274 , 101.98659 ],
#          [101.18597 , 144.47054 ],
#          [112.48172 , 146.7037  ],
#          [124.069885, 148.56726 ],
#          [129.09584 , 151.58356 ],
#          [134.10477 , 151.82535 ],
#          [142.07457 , 155.12416 ],
#          [148.30554 , 156.84198 ],
#          [137.81247 , 165.87851 ],
#          [129.80739 , 169.86899 ],
#          [122.73302 , 168.53221 ],
#          [115.008286, 164.55    ],
#          [108.713745, 157.24936 ],
#          [103.11382 , 145.41106 ],
#          [120.26531 , 152.04274 ],
#          [127.39096 , 154.36595 ],
#          [133.4519  , 155.72035 ],
#          [145.87614 , 156.56595 ],
#          [131.86722 , 161.25876 ],
#          [124.66736 , 160.81787 ],
#          [118.29024 , 157.65648 ]], dtype=float32),
#   array([[ 73.72511 ,  52.904984],
#          [ 67.419495,  69.67035 ],
#          [ 63.579338,  88.492   ],
#          [ 61.53703 , 105.134766],
#          [ 62.12141 , 128.3542  ],
#          [ 68.11824 , 149.40103 ],
#          [ 77.55745 , 167.41422 ],
#          [ 90.388535, 183.36761 ],
#          [109.116135, 195.09772 ],
#          [129.7717  , 193.93373 ],
#          [143.15431 , 184.83653 ],
#          [156.3062  , 175.28716 ],
#          [170.43332 , 161.73128 ],
#          [180.74855 , 145.39282 ],
#          [188.72002 , 130.91621 ],
#          [196.31256 , 115.77557 ],
#          [201.88672 ,  99.34274 ],
#          [ 98.150406,  67.65261 ],
#          [109.32458 ,  68.469536],
#          [119.79485 ,  71.635544],
#          [128.5203  ,  77.08484 ],
#          [135.13846 ,  82.171005],
#          [165.84598 ,  91.2257  ],
#          [173.60405 ,  89.347145],
#          [182.74338 ,  88.36481 ],
#          [191.52153 ,  88.42668 ],
#          [197.27522 ,  91.604904],
#          [146.29279 , 102.395935],
#          [142.93219 , 115.160614],
#          [139.78363 , 128.59697 ],
#          [136.58263 , 138.52017 ],
#          [121.29689 , 134.96243 ],
#          [125.779915, 139.17456 ],
#          [131.7709  , 142.70958 ],
#          [137.8847  , 142.61404 ],
#          [142.47267 , 141.34515 ],
#          [106.48747 ,  85.834694],
#          [114.29395 ,  87.8009  ],
#          [121.439865,  89.59328 ],
#          [128.12021 ,  92.53818 ],
#          [120.93805 ,  92.97927 ],
#          [112.701485,  91.29268 ],
#          [160.23047 , 101.32556 ],
#          [168.17372 , 100.982544],
#          [175.96814 , 103.27284 ],
#          [181.45348 , 104.31851 ],
#          [174.56326 , 106.767456],
#          [166.313   , 105.424835],
#          [100.8812  , 145.61816 ],
#          [112.30258 , 148.7312  ],
#          [122.900635, 151.10411 ],
#          [127.42621 , 154.2942  ],
#          [132.46962 , 154.62093 ],
#          [140.0329  , 157.79521 ],
#          [146.87494 , 158.9247  ],
#          [137.24338 , 164.65796 ],
#          [129.81195 , 167.29524 ],
#          [123.36592 , 165.90877 ],
#          [116.275734, 162.5168  ],
#          [109.765495, 156.12152 ],
#          [102.932396, 146.29306 ],
#          [119.707466, 154.32463 ],
#          [125.88109 , 157.1274  ],
#          [131.78343 , 158.42294 ],
#          [144.29556 , 158.54451 ],
#          [131.51657 , 159.50803 ],
#          [125.07187 , 158.81525 ],
#          [119.262566, 156.15727 ]], dtype=float32),
#   array([[ 77.67313 ,  55.608208],
#          [ 71.653175,  72.181786],
#          [ 67.50627 ,  90.44079 ],
#          [ 65.12805 , 107.900925],
#          [ 65.19992 , 131.8606  ],
#          [ 71.86319 , 152.47336 ],
#          [ 80.82664 , 169.70016 ],
#          [ 93.7166  , 184.75552 ],
#          [111.999245, 196.59084 ],
#          [132.4218  , 196.35628 ],
#          [146.10893 , 188.02072 ],
#          [158.86255 , 178.92816 ],
#          [172.7295  , 166.26923 ],
#          [183.39073 , 150.1277  ],
#          [191.51593 , 135.41536 ],
#          [199.13321 , 120.018845],
#          [204.8099  , 103.19118 ],
#          [101.92248 ,  68.95951 ],
#          [113.02892 ,  70.4861  ],
#          [123.54958 ,  73.84647 ],
#          [132.07352 ,  78.7122  ],
#          [138.41049 ,  84.355316],
#          [168.69536 ,  93.79209 ],
#          [176.76257 ,  92.22712 ],
#          [185.93141 ,  91.832016],
#          [194.66653 ,  92.11592 ],
#          [200.01912 ,  94.80849 ],
#          [149.5486  , 104.633575],
#          [145.97865 , 117.81444 ],
#          [142.85216 , 130.63914 ],
#          [139.79265 , 140.18521 ],
#          [124.46429 , 136.70029 ],
#          [128.87386 , 140.51001 ],
#          [134.70798 , 144.44678 ],
#          [140.87752 , 144.59439 ],
#          [145.61035 , 143.66948 ],
#          [110.30164 ,  87.24289 ],
#          [118.0153  ,  90.04025 ],
#          [125.21338 ,  91.804504],
#          [131.76382 ,  95.66196 ],
#          [124.53181 ,  95.41724 ],
#          [116.46021 ,  92.97603 ],
#          [162.96567 , 104.6595  ],
#          [110.430786, 155.91699 ],
#          [104.08359 , 145.56706 ],
#          [120.468414, 154.35983 ],
#          [126.75791 , 157.11882 ],
#          [132.47804 , 158.49242 ],
#          [145.30305 , 160.55933 ],
#          [132.18456 , 160.12442 ],
#          [125.84867 , 158.9162  ],
#          [119.89702 , 156.0978  ]], dtype=float32),
#   array([[ 83.271736,  51.36915 ],
#          [ 76.12647 ,  67.88547 ],
#          [ 70.83886 ,  86.03255 ],
#          [ 67.480316, 103.03325 ],
#          [ 65.89923 , 125.68948 ],
#          [ 70.7935  , 146.80327 ],
#          [ 79.48503 , 164.84444 ],
#          [ 91.27371 , 181.3958  ],
#          [109.72467 , 194.0711  ],
#          [130.45035 , 194.45204 ],
#          [145.46074 , 185.97867 ],
#          [158.95164 , 177.14476 ],
#          [173.51721 , 164.81114 ],
#          [184.84329 , 148.2303  ],
#          [193.55064 , 133.60536 ],
#          [201.24777 , 118.633255],
#          [207.27765 , 102.05884 ],
#          [104.40454 ,  65.39294 ],
#          [114.94163 ,  66.17915 ],
#          [125.55097 ,  69.98769 ],
#          [133.78214 ,  75.59947 ],
#          [139.92717 ,  81.32495 ],
#          [169.52142 ,  91.79767 ],
#          [177.63586 ,  90.945724],
#          [186.79578 ,  91.26759 ],
#          [195.5527  ,  91.95971 ],
#          [201.23712 ,  95.032906],
#          [149.90332 , 102.65596 ],
#          [145.6135  , 115.16759 ],
#          [142.19753 , 127.438416],
#          [138.33694 , 136.98132 ],
#          [123.72036 , 133.41104 ],
#          [127.89416 , 137.77782 ],
#          [133.59644 , 141.77216 ],
#          [139.54883 , 142.32156 ],
#          [144.32349 , 141.71912 ],
#          [111.99847 ,  83.45663 ],
#          [119.50149 ,  86.38032 ],
#          [126.78047 ,  88.51479 ],
#          [132.77177 ,  91.89661 ],
#          [126.087036,  91.847046],
#          [118.12764 ,  89.58625 ],
#          [163.86957 , 103.069   ],
#          [171.87666 , 103.26836 ],
#          [179.77956 , 105.48038 ],
#          [185.31783 , 106.66478 ],
#          [178.4724  , 109.26196 ],
#          [169.83734 , 107.86525 ],
#          [103.00443 , 143.6237  ],
#          [113.9509  , 146.72871 ],
#          [124.34012 , 149.68582 ],
#          [128.79056 , 153.0372  ],
#          [133.84413 , 153.63144 ],
#          [141.74426 , 157.25835 ],
#          [148.84253 , 160.8328  ],
#          [138.2903  , 165.34953 ],
#          [130.53613 , 167.87071 ],
#          [123.92469 , 165.95671 ],
#          [116.854294, 162.36365 ],
#          [110.91345 , 155.32803 ],
#          [105.01918 , 144.3834  ],
#          [121.32283 , 153.01611 ],
#          [127.40648 , 155.84346 ],
#          [133.18108 , 157.4631  ],
#          [146.29039 , 160.17622 ],
#          [132.61613 , 160.31056 ],
#          [126.10302 , 159.28394 ],
#          [120.334366, 155.82808 ]], dtype=float32),
#   array([[ 86.85479 ,  47.79972 ],
#          [ 79.39107 ,  64.00378 ],
#          [ 73.13486 ,  81.79096 ],
#          [ 68.99499 ,  98.54515 ],
#          [ 67.12798 , 121.62866 ],
#          [ 70.956665, 143.56161 ],
#          [ 78.31819 , 162.86855 ],
#          [ 90.03064 , 181.63017 ],
#          [108.90454 , 195.84718 ],
#          [130.3624  , 196.09192 ],
#          [145.43881 , 187.20374 ],
#          [159.21959 , 178.09843 ],
#          [173.83585 , 165.36201 ],
#          [186.13997 , 148.848   ],
#          [194.77193 , 134.74706 ],
#          [202.69748 , 120.28174 ],
#          [209.13417 , 103.747314],
#          [106.159744,  62.2853  ],
#          [117.076195,  64.62234 ],
#          [127.50764 ,  68.35554 ],
#          [135.745   ,  74.085144],
#          [142.03792 ,  80.30525 ],
#          [172.31482 ,  91.687454],
#          [180.46072 ,  91.041214],
#          [189.79826 ,  91.66995 ],
#          [198.47928 ,  92.80646 ],
#          [204.08276 ,  95.70885 ],
#          [151.75056 , 101.614   ],
#          [147.1978  , 114.15669 ],
#          [143.34726 , 127.33389 ],
#          [139.08055 , 136.76894 ],
#          [124.67313 , 133.1616  ],
#          [128.66309 , 136.99971 ],
#          [134.43031 , 141.15683 ],
#          [140.84346 , 141.60999 ],
#          [145.89873 , 141.00052 ],
#          [114.00079 ,  81.82562 ],
#          [121.225136,  84.86382 ],
#          [128.56033 ,  87.16514 ],
#          [134.91455 ,  91.355606],
#          [127.83889 ,  90.78607 ],
#          [119.66762 ,  87.891594],
#          [166.25679 , 102.36267 ],
#          [174.5199  , 102.40607 ],
#          [182.59567 , 105.24036 ],
#          [188.03021 , 106.32779 ],
#          [180.88138 , 109.2603  ],
#          [172.43346 , 106.96358 ],
#          [103.89974 , 141.86707 ],
#          [114.43473 , 145.42584 ],
#          [125.03922 , 148.65404 ],
#          [129.88727 , 152.20552 ],
#          [135.13895 , 152.85857 ],
#          [143.19254 , 156.55643 ],
#          [149.85675 , 160.03287 ],
#          [138.88808 , 167.08989 ],
#          [130.57214 , 169.72057 ],
#          [123.594536, 167.91507 ],
#          [115.92805 , 163.47646 ],
#          [110.532295, 155.20105 ],
#          [105.73748 , 142.72176 ],
#          [121.6691  , 151.97435 ],
#          [128.34433 , 154.99095 ],
#          [134.27432 , 157.02733 ],
#          [147.38266 , 159.43446 ],
#          [133.01248 , 161.39355 ],
#          [126.034996, 160.21503 ],
# ...
#          [ 93.03359 , 180.79758 ],
#          [110.64962 , 194.86531 ],
#          [132.02899 , 196.41463 ],
#          [148.8287  , 189.32129 ],
#          [162.759   , 181.56198 ],
#          [178.1452  , 169.4584  ],
#          [190.74712 , 153.33153 ],
#          [199.43896 , 139.40375 ],
#          [208.08879 , 124.286575],
#          [215.50249 , 107.38606 ],
#          [110.20011 ,  63.183983],
#          [120.64266 ,  65.389336],
#          [130.56801 ,  70.27729 ],
#          [138.134   ,  76.080795],
#          [144.1945  ,  82.64237 ],
#          [173.65892 ,  95.02684 ],
#          [182.0614  ,  94.689804],
#          [191.69775 ,  95.80003 ],
#          [200.91359 ,  98.40593 ],
#          [207.19206 , 101.61456 ],
#          [153.71057 , 104.235306],
#          [148.45525 , 117.26019 ],
#          [144.13487 , 130.60289 ],
#          [139.6526  , 139.99828 ],
#          [126.31077 , 135.12837 ],
#          [130.74973 , 139.5285  ],
#          [136.74246 , 144.26888 ],
#          [143.12341 , 144.99527 ],
#          [148.32683 , 144.26865 ],
#          [117.81556 ,  83.277054],
#          [124.89311 ,  86.275635],
#          [131.84009 ,  89.1568  ],
#          [137.8713  ,  93.290436],
#          [130.57004 ,  92.628235],
#          [123.351265,  89.31096 ],
#          [169.57356 , 106.14436 ],
#          [176.98508 , 106.99252 ],
#          [184.66202 , 109.67987 ],
#          [190.85306 , 111.90318 ],
#          [183.68723 , 113.33865 ],
#          [175.0521  , 111.01886 ],
#          [106.55945 , 141.44687 ],
#          [116.58171 , 145.85475 ],
#          [127.22113 , 150.61525 ],
#          [131.88225 , 154.36136 ],
#          [137.57437 , 155.15434 ],
#          [146.10416 , 159.31348 ],
#          [152.94025 , 163.07088 ],
#          [141.88002 , 167.2125  ],
#          [133.38943 , 168.57103 ],
#          [126.08902 , 166.66267 ],
#          [118.33678 , 162.23354 ],
#          [112.65538 , 154.18814 ],
#          [108.4031  , 142.6205  ],
#          [123.55452 , 153.18523 ],
#          [130.2096  , 157.14839 ],
#          [136.76328 , 159.09917 ],
#          [150.60219 , 162.28596 ],
#          [135.95056 , 160.89735 ],
#          [128.70706 , 159.26033 ],
#          [122.673416, 155.35727 ]], dtype=float32),
#   array([[ 91.74555 ,  51.818764],
#          [ 84.31072 ,  67.891106],
#          [ 77.31626 ,  83.968025],
#          [ 72.749435, 100.224106],
#          [ 70.152374, 122.92215 ],
#          [ 73.550644, 144.14658 ],
#          [ 80.41252 , 163.10652 ],
#          [ 90.85783 , 181.85089 ],
#          [109.00904 , 195.87784 ],
#          [130.4619  , 197.04625 ],
#          [147.42542 , 189.36679 ],
#          [161.25267 , 181.40594 ],
#          [176.45964 , 169.35086 ],
#          [189.35783 , 152.81448 ],
#          [198.19969 , 138.43065 ],
#          [206.64023 , 123.28581 ],
#          [213.98346 , 106.3176  ],
#          [108.89834 ,  63.794373],
#          [119.04341 ,  65.87273 ],
#          [129.16574 ,  70.84877 ],
#          [136.64682 ,  77.02342 ],
#          [142.87106 ,  83.25693 ],
#          [172.31982 ,  95.69878 ],
#          [180.48402 ,  95.59946 ],
#          [190.04433 ,  96.26715 ],
#          [199.33194 ,  97.720276],
#          [206.05664 , 101.090485],
#          [152.45622 , 104.7327  ],
#          [147.55922 , 117.85083 ],
#          [142.65259 , 130.87842 ],
#          [137.93053 , 140.20009 ],
#          [124.708374, 134.97258 ],
#          [129.1453  , 139.60924 ],
#          [134.90637 , 144.41277 ],
#          [141.25093 , 145.30219 ],
#          [146.476   , 144.43896 ],
#          [116.07981 ,  83.28907 ],
#          [123.20356 ,  86.39881 ],
#          [130.23016 ,  89.0137  ],
#          [136.03716 ,  93.19382 ],
#          [129.08745 ,  92.483505],
#          [121.71025 ,  89.43791 ],
#          [167.62178 , 105.721664],
#          [175.4511  , 107.347885],
#          [183.09967 , 110.1918  ],
#          [188.99341 , 111.69881 ],
#          [181.70477 , 113.51901 ],
#          [173.4541  , 110.93938 ],
#          [104.65221 , 141.3959  ],
#          [114.51881 , 145.94931 ],
#          [125.142204, 150.6578  ],
#          [130.00288 , 154.66231 ],
#          [135.72563 , 155.47398 ],
#          [144.29726 , 159.66246 ],
#          [151.26761 , 163.20811 ],
#          [139.78639 , 168.04152 ],
#          [131.18973 , 169.56262 ],
#          [123.74721 , 167.7343  ],
#          [115.95764 , 163.15474 ],
#          [110.33059 , 154.799   ],
#          [106.458755, 142.3312  ],
#          [121.60117 , 153.3893  ],
#          [128.26904 , 157.3969  ],
#          [134.96811 , 159.4424  ],
#          [148.80669 , 162.46796 ],
#          [133.87259 , 161.86215 ],
#          [126.43476 , 160.20544 ],
#          [120.31799 , 156.10222 ]], dtype=float32),
#   array([[ 91.756775,  51.593277],
#          [ 84.446304,  67.50981 ],
#          [ 77.622025,  83.111404],
#          [ 72.87751 ,  99.25145 ],
#          [ 70.6286  , 121.848236],
#          [ 73.6056  , 142.89336 ],
#          [ 80.34107 , 162.5735  ],
#          [ 90.95355 , 181.69287 ],
#          [109.29292 , 195.86955 ],
#          [130.86708 , 196.5085  ],
#          [147.21211 , 188.37872 ],
#          [161.09459 , 179.69041 ],
#          [176.0163  , 167.6234  ],
#          [188.73174 , 151.22394 ],
#          [197.75674 , 136.90193 ],
#          [206.20723 , 122.34885 ],
#          [213.40213 , 105.28827 ],
#          [109.693596,  63.021957],
#          [119.61645 ,  64.851875],
#          [129.60287 ,  69.19115 ],
#          [137.00955 ,  74.84693 ],
#          [143.21533 ,  81.24759 ],
#          [173.37094 ,  92.89441 ],
#          [181.26277 ,  92.35983 ],
#          [190.59567 ,  93.14911 ],
#          [199.46637 ,  95.57703 ],
#          [205.6465  ,  99.13939 ],
#          [152.80229 , 102.3651  ],
#          [148.25941 , 115.08165 ],
#          [143.41278 , 128.36905 ],
#          [138.60448 , 137.94426 ],
#          [125.64347 , 133.52786 ],
#          [129.55081 , 137.55034 ],
#          [135.3562  , 141.7717  ],
#          [141.94273 , 142.2853  ],
#          [147.56223 , 141.68504 ],
#          [116.60367 ,  81.9393  ],
#          [123.34713 ,  84.79646 ],
#          [130.5252  ,  87.37174 ],
#          [136.33379 ,  91.59097 ],
#          [129.48894 ,  90.96893 ],
#          [121.77849 ,  87.864235],
#          [168.12514 , 103.963715],
#          [176.13254 , 104.458115],
#          [183.38266 , 107.338   ],
#          [189.34843 , 109.24284 ],
#          [181.99898 , 110.67763 ],
#          [173.97939 , 108.694534],
#          [104.83204 , 141.05429 ],
#          [114.90044 , 144.58041 ],
#          [125.71043 , 148.97006 ],
#          [130.67368 , 152.98045 ],
#          [136.28244 , 153.86542 ],
#          [145.04362 , 157.84729 ],
#          [152.03342 , 160.81673 ],
#          [140.128   , 168.33954 ],
#          [131.17166 , 170.62251 ],
#          [123.46351 , 168.56235 ],
#          [115.62142 , 163.80319 ],
#          [110.21376 , 155.09186 ],
#          [106.70371 , 141.85524 ],
#          [122.18267 , 151.67693 ],
#          [128.97995 , 155.49646 ],
#          [135.76462 , 158.03513 ],
#          [149.52129 , 160.21053 ],
#          [133.86029 , 162.69504 ],
#          [126.08952 , 161.14427 ],
#          [119.85456 , 156.8566  ]], dtype=float32),
#   array([[ 90.292534,  50.890022],
#          [ 83.7146  ,  67.181046],
#          [ 76.806305,  83.46769 ],
#          [ 73.010284,  99.617294],
#          [ 70.56913 , 121.91377 ],
#          [ 73.78539 , 143.12628 ],
#          [ 80.690414, 162.28488 ],
#          [ 91.19946 , 180.83823 ],
#          [109.714386, 195.02567 ],
#          [130.85585 , 195.82431 ],
#          [146.7518  , 188.1385  ],
#          [160.65324 , 179.62616 ],
#          [175.24294 , 167.61215 ],
#          [187.47023 , 150.75069 ],
#          [196.31403 , 136.40211 ],
#          [204.73419 , 121.85971 ],
#          [211.65959 , 104.87471 ],
#          [108.289536,  63.075325],
#          [118.11096 ,  65.43324 ],
#          [128.0559  ,  69.42125 ],
#          [135.6724  ,  74.992805],
#          [142.04088 ,  81.49333 ],
#          [171.79778 ,  92.70549 ],
#          [179.71191 ,  92.21806 ],
#          [188.97162 ,  92.85593 ],
#          [197.88188 ,  94.7899  ],
#          [204.07751 ,  98.1541  ],
#          [151.74278 , 102.48445 ],
#          [147.01204 , 115.23134 ],
#          [142.32712 , 128.24718 ],
#          [137.72133 , 137.65582 ],
#          [125.12768 , 133.66096 ],
#          [128.97485 , 137.6868  ],
#          [134.73909 , 142.09709 ],
#          [141.15497 , 142.60446 ],
#          [146.66826 , 141.97014 ],
#          [115.616005,  82.50736 ],
#          [122.26006 ,  85.12823 ],
#          [129.4271  ,  87.72989 ],
#          [135.39615 ,  91.84849 ],
#          [128.29657 ,  91.20204 ],
#          [120.82027 ,  88.30222 ],
#          [167.14325 , 103.91853 ],
#          [175.02943 , 104.35487 ],
#          [182.0465  , 106.92201 ],
#          [187.84085 , 109.276276],
#          [180.67584 , 110.57176 ],
#          [173.05324 , 108.257675],
#          [104.65421 , 141.99677 ],
#          [114.84143 , 145.06802 ],
#          [125.684586, 148.87842 ],
#          [130.43794 , 152.32782 ],
#          [135.82417 , 153.03142 ],
#          [144.34676 , 156.90858 ],
#          [151.51788 , 160.91035 ],
#          [140.08415 , 167.16269 ],
#          [131.37201 , 169.5897  ],
#          [124.07799 , 167.55414 ],
#          [116.41535 , 163.01578 ],
#          [111.05314 , 154.78552 ],
#          [106.51862 , 142.72595 ],
#          [122.03349 , 151.84425 ],
#          [128.83974 , 155.07155 ],
#          [135.247   , 156.9936  ],
#          [148.95178 , 160.21904 ],
#          [133.91212 , 161.3449  ],
#          [126.58782 , 160.14267 ],
#          [120.45685 , 156.22449 ]], dtype=float32)],
#  array([[[[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          ...,
#
#          [[214, 215, 218],
#           [214, 215, 218],
#           [214, 215, 218],
#           ...,
#           [213, 213, 213],
#           [211, 211, 211],
#           [211, 211, 211]],
#
#          [[213, 214, 217],
#           [213, 214, 217],
#           [213, 214, 217],
#           ...,
#           [211, 211, 208],
#           [210, 210, 207],
#           [210, 210, 207]],
#
#          [[213, 214, 217],
#           [213, 214, 217],
#           [213, 214, 217],
#           ...,
#           [215, 215, 212],
#           [215, 215, 212],
#           [215, 215, 212]]],
#
#
#         [[[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          ...,
#
#          [[214, 215, 218],
#           [214, 215, 218],
#           [214, 215, 218],
#           ...,
#           [214, 212, 210],
#           [211, 209, 207],
#           [209, 207, 205]],
#
#          [[214, 216, 216],
#           [213, 215, 215],
#           [213, 215, 215],
#           ...,
#           [211, 211, 206],
#           [211, 209, 205],
#           [210, 208, 204]],
#
#          [[214, 216, 216],
#           [214, 216, 216],
#           [212, 214, 214],
#           ...,
#           [213, 213, 208],
#           [212, 210, 206],
#           [211, 209, 205]]],
#
#
#         [[[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          [[139, 163, 249],
#           [139, 163, 249],
#           [139, 163, 249],
#           ...,
#           [126, 156, 246],
#           [126, 156, 246],
#           [126, 156, 246]],
#
#          ...,
#
#          [[213, 214, 217],
#           [215, 216, 219],
#           [213, 214, 217],
#           ...,
#           [210, 208, 209],
#           [210, 208, 209],
#           [209, 207, 208]],
#
#          [[212, 217, 216],
#           [212, 217, 216],
#           [210, 215, 214],
#           ...,
#           [210, 208, 204],
#           [210, 208, 204],
#           [210, 208, 204]],
#
#          [[211, 216, 215],
#           [211, 216, 215],
#           [209, 214, 213],
#           ...,
#           [212, 210, 206],
#           [214, 212, 208],
#           [215, 213, 209]]],
#
#
#         ...,
#
#
#         [[[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [133, 164, 249],
#           [133, 164, 249],
#           [134, 165, 250]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [132, 163, 248],
#           [132, 163, 248],
#           [131, 162, 247]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [130, 159, 245],
#           [132, 161, 247],
#           [132, 161, 247]],
#
#          ...,
#
#          [[ 57,  50,  64],
#           [ 57,  50,  64],
#           [ 53,  46,  60],
#           ...,
#           [ 73,  64,  77],
#           [ 70,  61,  74],
#           [ 68,  59,  72]],
#
#          [[ 60,  53,  67],
#           [ 56,  49,  63],
#           [ 53,  46,  60],
#           ...,
#           [ 69,  60,  73],
#           [ 65,  56,  69],
#           [ 62,  53,  66]],
#
#          [[ 61,  54,  68],
#           [ 56,  49,  63],
#           [ 53,  46,  60],
#           ...,
#           [ 66,  57,  70],
#           [ 62,  53,  66],
#           [ 59,  50,  63]]],
#
#
#         [[[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [129, 158, 244],
#           [130, 159, 245],
#           [132, 161, 247]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [132, 161, 247],
#           [132, 161, 247],
#           [133, 162, 248]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [135, 161, 250],
#           [135, 161, 250],
#           [136, 162, 251]],
#
#          ...,
#
#          [[ 62,  55,  69],
#           [ 61,  54,  68],
#           [ 56,  49,  63],
#           ...,
#           [ 65,  56,  69],
#           [ 61,  52,  65],
#           [ 58,  49,  62]],
#
#          [[ 63,  56,  70],
#           [ 60,  53,  67],
#           [ 56,  49,  63],
#           ...,
#           [ 63,  54,  67],
#           [ 58,  49,  62],
#           [ 56,  47,  60]],
#
#          [[ 64,  57,  71],
#           [ 60,  53,  67],
#           [ 56,  49,  63],
#           ...,
#           [ 59,  50,  63],
#           [ 55,  46,  59],
#           [ 52,  43,  56]]],
#
#
#         [[[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [134, 163, 251],
#           [136, 163, 245],
#           [136, 163, 245]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [135, 164, 252],
#           [137, 164, 246],
#           [137, 164, 246]],
#
#          [[140, 164, 252],
#           [140, 164, 252],
#           [140, 164, 252],
#           ...,
#           [133, 161, 252],
#           [135, 161, 248],
#           [135, 161, 248]],
#
#          ...,
#
#          [[ 56,  49,  63],
#           [ 55,  48,  62],
#           [ 53,  46,  60],
#           ...,
#           [ 55,  46,  59],
#           [ 49,  40,  53],
#           [ 45,  36,  49]],
#
#          [[ 57,  50,  64],
#           [ 57,  50,  64],
#           [ 54,  47,  61],
#           ...,
#           [ 51,  42,  55],
#           [ 45,  36,  49],
#           [ 42,  33,  46]],
#
#          [[ 58,  51,  65],
#           [ 57,  50,  64],
#           [ 55,  48,  62],
#           ...,
#           [ 51,  42,  55],
#           [ 47,  38,  51],
#           [ 43,  34,  47]]]], dtype=uint8))

# %% [markdown]
# ## Interpolation

# %%
def linear_interpolation(start_idx: int, end_idx: int, landmarks):
    """Defines a linear interpolation function to interpolate missing landmarks between indices

    Args:
        start_idx (int): An integer defining the starting index
        end_idx (int): An integer defining the stopping index
        landmarks: An array of size 68 containing the (x,y) values of the facial landmarks

    Returns:
        landmarks array after the missing points have been interpolated.
    """
    start_landmarks = landmarks[start_idx]
    end_landmarks = landmarks[end_idx]
    delta_idx = end_idx - start_idx
    delta_landmarks = end_landmarks - start_landmarks

    # Apply linear interpolation formula
    for idx in range(1, delta_idx):
        landmarks[idx + start_idx] = start_landmarks + delta_landmarks/delta_idx * idx
    return landmarks

# %%
import os

os.path.exists('landmarks/custom_df_with_landmarks2.pkl')
# Out:
# False

# %%
pd.read_pickle('dataframe/custom.pkl').iloc[0]['path']
filename = 'data/custom_dataset/YESTERDAY/yesterday (1).MP4'
landmark_path = f"landmarks/computed/{str(filename).split('/')[-2]}/train/{str(filename).split('/')[-1].split('.')[-2]}.pkl"
os.path.exists(landmark_path)
# Out:
# True

# %%
def landmarks_interpolation(landmarks):
    """Adds the missing landmarks to the landmarks array

    Args:
        landmarks: An array containing all the detected landmarks

    Returns:
        landmarks array filled in with missing landmarks
    """
    # Obtain indices of all the valid landmarks (i.e landmarks not None)
    valid_landmarks_idx = [idx for idx, _ in enumerate(landmarks) if _ is not None]
    
    if not valid_landmarks_idx:
        return

    # For middle parts of the landmarks array
    for idx in range(1, len(valid_landmarks_idx)):
        # If the valid landmarks indices are adjacent then skip to next iteration
        if valid_landmarks_idx[idx]-valid_landmarks_idx[idx-1] > 1:
            landmarks = linear_interpolation(start_idx=valid_landmarks_idx[idx-1],
                                            end_idx=valid_landmarks_idx[idx],
                                            landmarks=landmarks)

    # For beginning and ending parts of the landmarks array
    valid_landmarks_idx = [idx for idx, _ in enumerate(landmarks) if _ is not None]
    landmarks[:valid_landmarks_idx[0]] = [landmarks[valid_landmarks_idx[0]]] * valid_landmarks_idx[0]
    landmarks[valid_landmarks_idx[-1]:] = [landmarks[valid_landmarks_idx[-1]]] * (len(landmarks) - valid_landmarks_idx[-1])

    return landmarks

# %% [markdown]
# ### Modular

# %%
# %%writefile modular/interpolation.py

"""Defines the interpolation functions to fill the missing landmarks in the landmarks array"""

def linear_interpolation(start_idx: int, end_idx: int, landmarks):
    """Defines a linear interpolation function to interpolate missing landmarks between indices

    Args:
        start_idx (int): An integer defining the starting index
        end_idx (int): An integer defining the stopping index
        landmarks: An array of size 68 containing the (x,y) values of the facial landmarks

    Returns:
        landmarks array after the missing points have been interpolated.
    """
    start_landmarks = landmarks[start_idx]
    end_landmarks = landmarks[end_idx]
    delta_idx = end_idx - start_idx
    delta_landmarks = end_landmarks - start_landmarks

    # Apply linear interpolation formula
    for idx in range(1, delta_idx):
        landmarks[idx + start_idx] = start_landmarks + delta_landmarks/delta_idx * idx
    return landmarks


def landmarks_interpolation(landmarks):
    """Adds the missing landmarks to the landmarks array

    Args:
        landmarks: An array containing all the detected landmarks

    Returns:
        landmarks array filled in with missing landmarks
    """
    # Obtain indices of all the valid landmarks (i.e landmarks not None)
    valid_landmarks_idx = [idx for idx, _ in enumerate(landmarks) if _ is not None]
    
    if not valid_landmarks_idx:
        return

    # For middle parts of the landmarks array
    for idx in range(1, len(valid_landmarks_idx)):
        # If the valid landmarks indices are adjacent then skip to next iteration
        if valid_landmarks_idx[idx]-valid_landmarks_idx[idx-1] > 1:
            landmarks = linear_interpolation(start_idx=valid_landmarks_idx[idx-1],
                                            end_idx=valid_landmarks_idx[idx],
                                            landmarks=landmarks)

    # For beginning and ending parts of the landmarks array
    valid_landmarks_idx = [idx for idx, _ in enumerate(landmarks) if _ is not None]
    landmarks[:valid_landmarks_idx[0]] = [landmarks[valid_landmarks_idx[0]]] * valid_landmarks_idx[0]
    landmarks[valid_landmarks_idx[-1]:] = [landmarks[valid_landmarks_idx[-1]]] * (len(landmarks) - valid_landmarks_idx[-1])

    return landmarks

# %% [markdown]
# ## Affine Transformation

# %%
# %%writefile modular/transform.py

import cv2

class VideoProcess:
    def __init__(self, mean_landmarks_path: str):
        # For warping the frames
        self.mean_landmarks = np.load(mean_landmarks_path)
        self.stable_points=(28, 33, 36, 39, 42, 45, 48, 54)
        self.reference_landmarks = np.vstack([self.mean_landmarks[x] for x in self.stable_points])

        # Cropping
        self.crop_height = 96
        self.crop_width = 96
        self.temporal_window = 12

    def __call__(self, video_path, landmarks):
        video,_,_ = read_video(str(video_path), pts_unit='sec')
        landmarks = landmarks_interpolation(landmarks)

        if not landmarks or len(landmarks) < self.temporal_window:
            return 

        mouth_rois = self.crop_video(video.numpy(), landmarks)
        return mouth_rois

    
    # Affine Transformation (Rotation, Translation and Scaling)
    def _get_transform(self, src_points: np.ndarray) -> np.ndarray:
        transform, _ = cv2.estimateAffinePartial2D(src_points, self.reference_landmarks, method=cv2.LMEDS)
        return transform

    def warp_frame(self, frame, landmarks):
        # Convert frame to grayscale
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        
        # Extract only stable points from current landmarks
        stable_points_landmarks = np.vstack([landmarks[x] for x in self.stable_points])

        transform_matrix = self._get_transform(stable_points_landmarks)
        transformed_frame = cv2.warpAffine(frame, transform_matrix, dsize=(256,256))
        transformed_landmarks = np.matmul(landmarks, transform_matrix[:, :2].transpose()) + transform_matrix[:, 2].transpose()
        
        return transformed_frame, transformed_landmarks


    # Crop Frames (Obtain Mouth ROI)
    def _cut_mouth(self, frame, landmarks, height, width):
        center_x, center_y = np.mean(landmarks, axis=0)

        # Calculate bounding box coordinates
        y_min = int(round(np.clip(center_y - height, 0, 256)))
        y_max = int(round(np.clip(center_y + height, 0, 256)))
        x_min = int(round(np.clip(center_x - width, 0, 256)))
        x_max = int(round(np.clip(center_x + width, 0, 256)))
        mouth_roi = frame[y_min:y_max, x_min:x_max]
        return mouth_roi

    def crop_video(self, video, landmarks_list):
        mouth_rois = []
        for idx, frame in enumerate(video):
            window_margin = min(self.temporal_window//2, idx, len(landmarks_list)-idx-1)

            average_landmarks_temporal = np.mean([landmarks_list[x] for x in range(idx-window_margin, idx+window_margin+1)], axis=0)
            average_landmarks_temporal += landmarks_list[idx].mean(axis=0) - average_landmarks_temporal.mean(axis=0)

            transformed_frame, transformed_landmarks = self.warp_frame(frame, average_landmarks_temporal)

            mouth = self._cut_mouth(transformed_frame, transformed_landmarks[48:68], height=self.crop_height//2, width=self.crop_width//2)

            mouth_rois.append(mouth)
        # print(mouth_rois)
        return np.array(mouth_rois)

# %% [markdown]
# ## Compute Landmarks
#
# **Do not execute**

# %%
# %%time

from modular.detector.detector import LandmarksDetector

landmark_detector = LandmarksDetector(device=device)
# Out:
# CPU times: user 1.65 s, sys: 45.8 ms, total: 1.7 s
# Wall time: 1.93 s

# %%
import os
from pathlib import Path

import pandas as pd

# %%
train_df = pd.read_pickle("dataframe/train_df_complete.pkl")
test_df = pd.read_pickle("dataframe/test_df_complete.pkl")
val_df = pd.read_pickle("dataframe/val_df_complete.pkl")

# labels = train_df['label'].unique()[:15]
# labels[-2:] = ['SCHOOL', 'MATTER']

labels = ['ALLEGATIONS', 'BUSINESSES', 'CONSERVATIVE', 'DIFFERENCE', 'EVERYTHING', 'FINANCIAL', 'GOVERNMENT', 'HAPPENING','IMMIGRATION', 'JUSTICE', 'KILLED', 'MANCHESTER', 'SIGNIFICANT', 'VIOLENCE', 'YESTERDAY']
print(labels)
train_df_2 = train_df[train_df['label'].isin(labels)].copy()
test_df_2 = test_df[test_df['label'].isin(labels)]
val_df_2 = val_df[val_df['label'].isin(labels)]

train_df_2.head()
# Out:
# ['ALLEGATIONS', 'BUSINESSES', 'CONSERVATIVE', 'DIFFERENCE', 'EVERYTHING', 'FINANCIAL', 'GOVERNMENT', 'HAPPENING', 'IMMIGRATION', 'JUSTICE', 'KILLED', 'MANCHESTER', 'SIGNIFICANT', 'VIOLENCE', 'YESTERDAY']
#                                                     path      label  split  \
# 60255  data/lipread_mp4/YESTERDAY/train/YESTERDAY_005...  YESTERDAY  train
# 60256  data/lipread_mp4/YESTERDAY/train/YESTERDAY_003...  YESTERDAY  train
# 60257  data/lipread_mp4/YESTERDAY/train/YESTERDAY_009...  YESTERDAY  train
# 60258  data/lipread_mp4/YESTERDAY/train/YESTERDAY_000...  YESTERDAY  train
# 60259  data/lipread_mp4/YESTERDAY/train/YESTERDAY_000...  YESTERDAY  train
#
#        duration
# 60255      0.41
# 60256      0.62
# 60257      0.63
# 60258      0.47
# 60259      0.57

# %%
train_df_2['label'].unique()
# Out:
# array(['YESTERDAY', 'GOVERNMENT', 'HAPPENING', 'IMMIGRATION',
#        'DIFFERENCE', 'ALLEGATIONS', 'KILLED', 'BUSINESSES', 'FINANCIAL',
#        'MANCHESTER', 'JUSTICE', 'EVERYTHING', 'CONSERVATIVE',
#        'SIGNIFICANT', 'VIOLENCE'], dtype=object)

# %%
# %%time
from tqdm.auto import tqdm

tqdm.pandas()
train_df_2['landmarks'] = train_df_2['path'].progress_apply(landmark_detector)
# Out:
#   0%|          | 0/14523 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:4
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/tqdm/std.py:920, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     917 # Apply the provided function (in **kwargs)
#     918 # on the df using our wrapper (which provides bar updating)
#     919 try:
# --> 920     return getattr(df, df_function)(wrapper, **kwargs)
#     921 finally:
#     922     t.close()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/tqdm/std.py:915, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     909 def wrapper(*args, **kwargs):
#     910     # update tbar correctly
#     911     # it seems `pandas apply` calls `func` twice
#     912     # on the first column/row to decide whether it can
#     913     # take a fast or slow code path; so stop when t.total==t.n
#     914     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 915     return func(*args, **kwargs)
#
# File ~/Desktop/Project/modular/detector/detector.py:41, in LandmarksDetector.__call__(self, filename)
#      38 cropped_frames = []
#      40 for frame in frames:
# ---> 41     face_boxes = self.face_detector(image=frame, rgb=False)
#      42     face_points, _ = self.landmark_detector(image=frame, face_boxes=face_boxes)
#      44     if len(face_boxes) == 0:
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Desktop/Project/detector/face_detection/ibug/face_detection/retina_face/retina_face_predictor.py:68, in RetinaFacePredictor.__call__(self, image, rgb)
#      66 image = torch.from_numpy(image).unsqueeze(0).float().to(self.device)
#      67 scale = torch.Tensor([im_width, im_height, im_width, im_height]).to(self.device)
# ---> 68 loc, conf, landms = self.net(image)
#      69 image_size = (im_height, im_width)
#      70 if self.priors is None or self.previous_size != image_size:
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Desktop/Project/detector/face_detection/ibug/face_detection/retina_face/retina_face.py:96, in RetinaFace.forward(self, inputs)
#      95 def forward(self, inputs):
# ---> 96     out = self.body(inputs)
#      98     # FPN
#      99     fpn = self.fpn(out)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torchvision/models/_utils.py:69, in IntermediateLayerGetter.forward(self, x)
#      67 out = OrderedDict()
#      68 for name, module in self.items():
# ---> 69     x = module(x)
#      70     if name in self.return_layers:
#      71         out_name = self.return_layers[name]
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torchvision/models/resnet.py:147, in Bottleneck.forward(self, x)
#     144 identity = x
#     146 out = self.conv1(x)
# --> 147 out = self.bn1(out)
#     148 out = self.relu(out)
#     150 out = self.conv2(out)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1682, in Module.__getattr__(self, name)
#    1673         self._backward_pre_hooks = OrderedDict()
#    1675 # On the return type:
#    1676 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1677 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1680 # See full discussion on the problems with returning `Union` here
#    1681 # https://github.com/microsoft/pyright/issues/4213
# -> 1682 def __getattr__(self, name: str) -> Any:
#    1683     if '_parameters' in self.__dict__:
#    1684         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
# test_df = pd.read_pickle("dataframe/test_df_50lab_1000train_50val_50test.pkl")
# val_df = pd.read_pickle("dataframe/val_df_50lab_1000train_50val_50test.pkl")

# %%
# %%time

test_df['landmarks'] = test_df['path'].progress_apply(landmark_detector)
val_df['landmarks'] = val_df['path'].progress_apply(landmark_detector)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/tqdm/std.py:920, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     917 # Apply the provided function (in **kwargs)
#     918 # on the df using our wrapper (which provides bar updating)
#     919 try:
# --> 920     return getattr(df, df_function)(wrapper, **kwargs)
#     921 finally:
#     922     t.close()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2920, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/tqdm/std.py:915, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     909 def wrapper(*args, **kwargs):
#     910     # update tbar correctly
#     911     # it seems `pandas apply` calls `func` twice
#     912     # on the first column/row to decide whether it can
#     913     # take a fast or slow code path; so stop when t.total==t.n
#     914     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 915     return func(*args, **kwargs)
#
# File ~/Desktop/Project/modular/detector/detector.py:25, in LandmarksDetector.__call__(self, filename)
#      23 for frame in frames:
#      24     face_boxes = self.face_detector(image=frame, rgb=False)
# ---> 25     face_points, _ = self.landmark_detector(image=frame, face_boxes=face_boxes)
#      27     if len(face_boxes) == 0:
#      28         landmarks.append(None)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Desktop/Project/detector/face_alignment/ibug/face_alignment/fan/fan_predictor.py:103, in FANPredictor.__call__(self, image, face_boxes, rgb, return_features)
#      99 face_patches = torch.from_numpy(np.array(face_patches).transpose(
#     100     (0, 3, 1, 2)).astype(np.float32)).to(self.device) / 255.0
#     102 # Get heatmaps
# --> 103 heatmaps, stem_feats, hg_feats = self.net(face_patches)
#     105 # Get landmark coordinates and scores
#     106 landmarks, landmark_scores = self._decode(heatmaps)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/VSR/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# KeyboardInterrupt:

# %%
val_df.head()
# Out:
#                                                path     label split
# 0  data/lipread_mp4/HUNDREDS/val/HUNDREDS_00041.mp4  HUNDREDS   val
# 1  data/lipread_mp4/HUNDREDS/val/HUNDREDS_00038.mp4  HUNDREDS   val
# 2  data/lipread_mp4/HUNDREDS/val/HUNDREDS_00024.mp4  HUNDREDS   val
# 3  data/lipread_mp4/HUNDREDS/val/HUNDREDS_00019.mp4  HUNDREDS   val
# 4  data/lipread_mp4/HUNDREDS/val/HUNDREDS_00018.mp4  HUNDREDS   val

# %%
custom_df = pd.read_pickle('dataframe/custom_test.pkl')
custom_df
# Out:
#                                                  path         label  split
# 0   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 1   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 2   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 3   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 4   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 5   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 6   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 7   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 8   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 9   data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 10  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 11  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 12  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 13  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 14  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 15  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 16  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 17  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 18  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 19  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 20  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 21  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 22  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 23  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 24  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 25  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 26  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 27  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 28  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 29  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 30  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 31  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 32  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 33  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 34  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 35  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 36  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 37  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 38  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 39  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 40  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 41  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 42  data/custom_data_test/VIOLENCE/WIN_20240226_11...      VIOLENCE  train
# 43  data/custom_data_test/VIOLENCE/WIN_20240226_11...      VIOLENCE  train
# 44  data/custom_data_test/VIOLENCE/WIN_20240226_11...      VIOLENCE  train

# %%
from tqdm.auto import tqdm

tqdm.pandas()

custom_df['landmarks'] = custom_df['path'].progress_apply(landmark_detector)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
custom_df
# Out:
#                                                  path         label  split  \
# 0   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 1   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 2   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 3   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 4   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 5   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 6   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 7   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 8   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 9   data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 10  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 11  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 12  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 13  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 14  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 15  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 16  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 17  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 18  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 19  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 20  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 21  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 22  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 23  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 24  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 25  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 26  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
#
# 0      data/custom_dataset/YESTERDAY/yesterday (1).MP4  YESTERDAY  train
# 1    data/custom_dataset/YESTERDAY/WIN_20240225_19_...  YESTERDAY  train
# 2          data/custom_dataset/YESTERDAY/yesterday.MP4  YESTERDAY  train
# 3    data/custom_dataset/YESTERDAY/WIN_20240226_07_...  YESTERDAY  train
# 4    data/custom_dataset/YESTERDAY/WIN_20240225_19_...  YESTERDAY  train
# ..                                                 ...        ...    ...
# 505      data/custom_dataset/VIOLENCE/violence (1).MP4   VIOLENCE  train
# 506  data/custom_dataset/VIOLENCE/WIN_20240226_07_4...   VIOLENCE  train
# 507  data/custom_dataset/VIOLENCE/VID20240225145421...   VIOLENCE  train
# 508   data/custom_dataset/VIOLENCE/20240225_092431.mp4   VIOLENCE  train
# 509  data/custom_dataset/VIOLENCE/Messenger_creatio...   VIOLENCE  train
#
#                                              landmarks
# 0    [[[226.90822, 344.35336], [227.90533, 384.0270...
# 1    [[[128.1395, 108.636604], [128.95157, 120.2559...
# 2    [[[231.60281, 345.09332], [233.02394, 384.7119...
# 3    [[[802.81506, 453.57693], [800.1127, 503.1351]...
# 4    [[[127.156525, 107.67921], [127.999985, 119.45...
# ..                                                 ...
# 505  [[[208.98694, 524.4233], [211.0667, 575.6835],...
# 506  [[[796.77594, 460.55255], [796.0493, 511.60367...
# 507  [[[136.94447, 758.7581], [135.75381, 861.5562]...
# 508  [[[112.912445, 823.55457], [121.42131, 905.960...
# 509  [[[41.133705, 364.0339], [40.66616, 394.30145]...
#
# [510 rows x 4 columns]

# %%
custom_df.to_pickle("landmarks/custom_df_test_with_landmarks.pkl")

# %%
test_df.head()
# Out:
# KeyboardInterrupt

# %%
train_df.to_pickle("landmarks/train_df_with_landmarks.pkl")
test_df.to_pickle("landmarks/test_df_with_landmarks.pkl")
val_df.to_pickle("landmarks/val_df_with_landmarks.pkl")

# %% [markdown]
# ### Save as .pkl file
#
# Save the landmarks in `landmarks/<label>/<split>/filename.pkl`
# > Eg. landmarks/HUNDREDS/train/HUNDREDS_00001.pkl

# %%
import os
import numpy as np
import pandas as pd
import pickle

output_directory = "landmarks/computed/"

def save_landmarks(df: pd.DataFrame) -> None:
    for idx, row in df.iterrows():
        components = str(row['path']).split('/')
        label = components[-2]
        split = 'test'
        filename = components[-1].split('.')[0]
        # print(components)
        # Create directory 
        save_dir = os.path.join(output_directory, label, split)
        os.makedirs(save_dir, exist_ok=True)


        # Save landmarks
        file_path = os.path.join(save_dir, filename+'.pkl')
        with open(file_path, 'wb') as file:
            pickle.dump(row['landmarks'], file)

# %%
save_landmarks(custom_df)

# %%
train_df = pd.read_pickle('landmarks/train_df_with_landmarks.pkl')
test_df = pd.read_pickle('landmarks/test_df_with_landmarks.pkl')
val_df = pd.read_pickle('landmarks/val_df_with_landmarks.pkl')

# %%
# %%time

save_landmarks(train_df)
save_landmarks(test_df)
save_landmarks(val_df)
# Out:
# CPU times: user 8.77 s, sys: 2.82 s, total: 11.6 s
# Wall time: 12.2 s

# %%
test_df
# Out:
#                                                    path     label split  \
# 0     data/lipread_mp4/HUNDREDS/test/HUNDREDS_00041.mp4  HUNDREDS  test
# 1     data/lipread_mp4/HUNDREDS/test/HUNDREDS_00038.mp4  HUNDREDS  test
# 2     data/lipread_mp4/HUNDREDS/test/HUNDREDS_00024.mp4  HUNDREDS  test
# 3     data/lipread_mp4/HUNDREDS/test/HUNDREDS_00019.mp4  HUNDREDS  test
# 4     data/lipread_mp4/HUNDREDS/test/HUNDREDS_00018.mp4  HUNDREDS  test
# ...                                                 ...       ...   ...
# 2495        data/lipread_mp4/GREAT/test/GREAT_00044.mp4     GREAT  test
# 2496        data/lipread_mp4/GREAT/test/GREAT_00001.mp4     GREAT  test
# 2497        data/lipread_mp4/GREAT/test/GREAT_00004.mp4     GREAT  test
# 2498        data/lipread_mp4/GREAT/test/GREAT_00009.mp4     GREAT  test
# 2499        data/lipread_mp4/GREAT/test/GREAT_00023.mp4     GREAT  test
#
#                                               landmarks
# 0     [[[71.31809, 85.32948], [70.35795, 101.36151],...
# 1     [[[77.19481, 118.160805], [79.41128, 132.01007...
# 2     [[[50.837456, 75.2955], [53.087498, 94.72337],...
# 3     [[[72.97648, 90.28793], [73.85288, 107.57341],...
# 4     [[[61.28248, 113.27446], [63.205994, 128.76273...
# ...                                                 ...
# 2495  [[[54.5991, 100.90286], [57.263668, 117.41515]...
# 2496  [[[33.813316, 105.22418], [36.958332, 123.7727...
# 2497  [[[53.652363, 117.90432], [56.6435, 133.02452]...
# 2498  [[[75.98874, 88.40811], [75.49105, 105.41622],...
# 2499  [[[117.80007, 101.12826], [115.62211, 113.6936...
#
# [2500 rows x 4 columns]

# %%
pd.read_pickle('landmarks/computed/ALLEGATIONS/train/0nAth7il.pkl')[0]
# Out:
# array([[ 50.581818, 311.6434  ],
#        [ 51.75711 , 340.17905 ],
#        [ 55.541824, 369.35757 ],
#        [ 58.95862 , 396.19623 ],
#        [ 67.01491 , 425.0455  ],
#        [ 81.109146, 449.26828 ],
#        [ 98.15019 , 468.10336 ],
#        [122.61534 , 486.0556  ],
#        [157.22885 , 497.19052 ],
#        [191.4779  , 487.25833 ],
#        [212.73407 , 470.80945 ],
#        [229.40482 , 453.4158  ],
#        [244.17368 , 429.0011  ],
#        [252.38278 , 398.9055  ],
#        [257.01202 , 371.00705 ],
#        [260.14108 , 342.25797 ],
#        [260.81662 , 313.32684 ],
#        [ 74.09561 , 272.73053 ],
#        [ 87.01955 , 258.74313 ],
#        [103.12067 , 254.42696 ],
#        [119.57539 , 257.92896 ],
#        [134.82164 , 261.9857  ],
#        [193.44733 , 262.9478  ],
#        [205.98569 , 260.5016  ],
#        [221.38959 , 259.50357 ],
#        [236.4321  , 261.51248 ],
#        [248.34924 , 273.99298 ],
#        [164.72249 , 302.70505 ],
#        [165.42813 , 324.3053  ],
#        [166.69516 , 344.1984  ],
#        [167.51111 , 363.05386 ],
#        [145.46962 , 378.3531  ],
#        [153.59772 , 379.78055 ],
#        [165.41228 , 381.17157 ],
#        [175.79446 , 379.46024 ],
#        [183.53543 , 378.59396 ],
#        [ 92.12947 , 304.39618 ],
#        [104.46904 , 301.24646 ],
#        [117.027725, 299.9196  ],
#        [131.04182 , 302.54474 ],
#        [118.42183 , 305.83212 ],
#        [105.05542 , 307.32654 ],
#        [193.89813 , 303.70233 ],
#        [206.11981 , 301.70306 ],
#        [219.83423 , 303.04517 ],
#        [230.43631 , 304.90082 ],
#        [219.88705 , 308.55783 ],
#        [205.50095 , 307.73572 ],
#        [117.400024, 416.62933 ],
#        [135.21327 , 409.30557 ],
#        [155.18474 , 404.83157 ],
#        [164.7548  , 407.45328 ],
#        [174.4132  , 404.33304 ],
#        [192.43597 , 409.34213 ],
#        [206.38828 , 416.93173 ],
#        [190.535   , 431.11188 ],
#        [177.78629 , 439.08466 ],
#        [164.08223 , 440.02286 ],
#        [149.44939 , 438.31842 ],
#        [135.1693  , 431.1161  ],
#        [122.01607 , 416.44385 ],
#        [151.24983 , 416.18713 ],
#        [163.85347 , 415.9718  ],
#        [176.17975 , 415.65198 ],
#        [202.30734 , 416.72104 ],
#        [176.73569 , 424.4932  ],
#        [163.79108 , 425.75418 ],
#        [150.82553 , 424.1515  ]], dtype=float32)

# %%
train_df_2.iloc[0]['path']
# Out:
# PosixPath('data/lipread_mp4/YESTERDAY/train/YESTERDAY_00553.mp4')

# %%
import os
import pandas as pd
import pickle

# Assuming you have a DataFrame named df with a column 'path'

# Function to read landmarks from .pkl files
def read_landmarks(file_path):
    with open(file_path, 'rb') as f:
        landmarks = pickle.load(f)
    return landmarks

# Create a list to store the landmarks data
landmarks_data = []

# Iterate over each row in the DataFrame
for index, row in tqdm(train_df_2.iterrows(), total=len(train_df_2)):
    path = str(row['path'])
    parts = path.split('/')
    label = parts[2]
    split = parts[3]
    video = parts[4].split('.')[0]  # Remove file extension
    landmarks_path = os.path.join('landmarks', 'computed', label, split, video + '.pkl')
    
    # Check if landmarks file exists
    if os.path.exists(landmarks_path):
        landmarks = read_landmarks(landmarks_path)
        
        # Append the information to the landmarks data list
        landmarks_data.append({'label': label,
                               'split': split,
                               'path': path,
                               'landmarks': landmarks})

# Create a DataFrame from the list of landmarks data
train_landmarks_df = pd.DataFrame(landmarks_data)

# Now, landmarks_df contains all the landmarks information
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 17
#      14 landmarks_data = []
#      16 # Iterate over each row in the DataFrame
# ---> 17 for index, row in tqdm(train_df_2.iterrows(), total=len(train_df_2)):
#      18     path = str(row['path'])
#      19     parts = path.split('/')
#
# NameError: name 'train_df_2' is not defined

# %%
test_landmarks_df
# Out:
#          label split                                               path  \
# 0    YESTERDAY  test  data/lipread_mp4/YESTERDAY/test/YESTERDAY_0005...
# 1    YESTERDAY  test  data/lipread_mp4/YESTERDAY/test/YESTERDAY_0001...
# 2    YESTERDAY  test  data/lipread_mp4/YESTERDAY/test/YESTERDAY_0003...
# 3    YESTERDAY  test  data/lipread_mp4/YESTERDAY/test/YESTERDAY_0000...
# 4    YESTERDAY  test  data/lipread_mp4/YESTERDAY/test/YESTERDAY_0003...
# ..         ...   ...                                                ...
# 745   VIOLENCE  test  data/lipread_mp4/VIOLENCE/test/VIOLENCE_00023.mp4
# 746   VIOLENCE  test  data/lipread_mp4/VIOLENCE/test/VIOLENCE_00004.mp4
# 747   VIOLENCE  test  data/lipread_mp4/VIOLENCE/test/VIOLENCE_00014.mp4
# 748   VIOLENCE  test  data/lipread_mp4/VIOLENCE/test/VIOLENCE_00012.mp4
# 749   VIOLENCE  test  data/lipread_mp4/VIOLENCE/test/VIOLENCE_00027.mp4
#
#                                              landmarks
# 0    [[[56.91247, 101.05174], [58.089928, 117.58732...
# 1    [[[59.722687, 105.552795], [60.753757, 122.438...
# 2    [[[81.9126, 91.7889], [79.251686, 107.424355],...
# 3    [[[46.818714, 84.76558], [47.848415, 103.99255...
# 4    [[[74.09661, 106.67766], [74.54109, 120.891075...
# ..                                                 ...
# 745  [[[77.40906, 103.88178], [77.03793, 119.57168]...
# 746  [[[19.124844, 86.63643], [19.902966, 107.10586...
# 747  [[[55.79677, 103.47276], [57.241734, 120.35667...
# 748  [[[58.2957, 93.58083], [61.050842, 110.378944]...
# 749  [[[84.54883, 92.65149], [84.374626, 108.53039]...
#
# [750 rows x 4 columns]

# %% [markdown]
# ## Compute Mouth ROI
#
# **Do not execute**

# %%
video_process = VideoProcess(mean_landmarks_path='mean_landmarks/20words_mean_face.npy')

# %%
custom_df = pd.read_pickle('landmarks/custom_df_test_with_landmarks.pkl')
custom_df
# Out:
#                                                  path         label  split  \
# 0   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 1   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 2   data/custom_data_test/YESTERDAY/WIN_20240226_1...     YESTERDAY  train
# 3   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 4   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 5   data/custom_data_test/GOVERNMENT/WIN_20240226_...    GOVERNMENT  train
# 6   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 7   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 8   data/custom_data_test/HAPPENING/WIN_20240226_1...     HAPPENING  train
# 9   data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 10  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 11  data/custom_data_test/IMMIGRATION/WIN_20240226...   IMMIGRATION  train
# 12  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 13  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 14  data/custom_data_test/DIFFERENCE/WIN_20240226_...    DIFFERENCE  train
# 15  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 16  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 17  data/custom_data_test/ALLEGATIONS/WIN_20240226...   ALLEGATIONS  train
# 18  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 19  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 20  data/custom_data_test/KILLED/WIN_20240226_11_2...        KILLED  train
# 21  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 22  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 23  data/custom_data_test/BUSINESSES/WIN_20240226_...    BUSINESSES  train
# 24  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 25  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 26  data/custom_data_test/FINANCIAL/WIN_20240226_1...     FINANCIAL  train
# 27  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 28  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 29  data/custom_data_test/MANCHESTER/WIN_20240226_...    MANCHESTER  train
# 30  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 31  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 32  data/custom_data_test/JUSTICE/WIN_20240226_11_...       JUSTICE  train
# 33  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 34  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 35  data/custom_data_test/EVERYTHING/WIN_20240226_...    EVERYTHING  train
# 36  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 37  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 38  data/custom_data_test/CONSERVATIVE/WIN_2024022...  CONSERVATIVE  train
# 39  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 40  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 41  data/custom_data_test/SIGNIFICANT/WIN_20240226...   SIGNIFICANT  train
# 42  data/custom_data_test/VIOLENCE/WIN_20240226_11...      VIOLENCE  train
# 43  data/custom_data_test/VIOLENCE/WIN_20240226_11...      VIOLENCE  train
idx, row in tqdm(df.iterrows(), total=df.shape[0]):
        path = str(row['path'])
        mouth_roi = video_process(path, row['landmarks'])

        label = row['label']
        filename = path.split('/')[-1]
        split = 'test'

        filename = filename.split('.')[0]

        file_path = os.path.join(save_path,label,split)

        os.makedirs(file_path, exist_ok=True)

        npy_file_path = os.path.join(file_path, f"{filename}.npy")
        np.save(npy_file_path, arr=mouth_roi)

# %%
save_mouth_rois(custom_df)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]

# %%
# %%time
save_mouth_rois(pd.concat([train_df, test_df, val_df]))
# Out:
#   0%|          | 0/53962 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# Cell In[18], line 11, in save_mouth_rois(df)
#       9 for idx, row in tqdm(df.iterrows(), total=df.shape[0]):
#      10     path = str(row['path'])
# ---> 11     mouth_roi = video_process(path, row['landmarks'])
#      13     label = row['label']
#      14     split, filename = path.split('/')[-2:]
#
# Cell In[5], line 22, in VideoProcess.__call__(self, video_path, landmarks)
#      19 if not landmarks or len(landmarks) < self.temporal_window:
#      20     return
# ---> 22 mouth_rois = self.crop_video(video.numpy(), landmarks)
#      23 return mouth_rois
#
# Cell In[5], line 65, in VideoProcess.crop_video(self, video, landmarks_list)
#      62 average_landmarks_temporal = np.mean([landmarks_list[x] for x in range(idx-window_margin, idx+window_margin+1)], axis=0)
#      63 average_landmarks_temporal += landmarks_list[idx].mean(axis=0) - average_landmarks_temporal.mean(axis=0)
# ---> 65 transformed_frame, transformed_landmarks = self.warp_frame(frame, average_landmarks_temporal)
#      67 mouth = self._cut_mouth(transformed_frame, transformed_landmarks[48:68], height=self.crop_height//2, width=self.crop_width//2)
#      69 mouth_rois.append(mouth)
#
# Cell In[5], line 39, in VideoProcess.warp_frame(self, frame, landmarks)
#      36 stable_points_landmarks = np.vstack([landmarks[x] for x in self.stable_points])
#      38 transform_matrix = self._get_transform(stable_points_landmarks)
# ---> 39 transformed_frame = cv2.warpAffine(frame, transform_matrix, dsize=(256,256))
#      40 transformed_landmarks = np.matmul(landmarks, transform_matrix[:, :2].transpose()) + transform_matrix[:, 2].transpose()
#      42 return transformed_frame, transformed_landmarks
#
# KeyboardInterrupt:

# %%
from multiprocessing import Pool
from tqdm.auto import tqdm

def save_mouth_roi_parallel(args):
    idx, row, save_path = args
    path = str(row['path'])
    mouth_roi = video_process(path, row['landmarks'])

    label = row['label']
    filename = path.split('/')[-1]
    split = 'train'

    filename = filename.split('.')[0]

    file_path = os.path.join(save_path, label, split)
    os.makedirs(file_path, exist_ok=True)

    npy_file_path = os.path.join(file_path, f"{filename}.npy")
    np.save(npy_file_path, arr=mouth_roi)

def save_mouth_rois_parallel(df: pd.DataFrame, batch_size: int=5, desc: str = None) -> None:
    save_path = 'mouth/roi/'

    for batch_df in tqdm(np.array_split(df, len(df) // batch_size), desc=desc):
        args_list = [(idx, row, save_path) for idx, row in batch_df.iterrows()]

        with Pool(processes=os.cpu_count()) as pool:
            list(pool.imap_unordered(save_mouth_roi_parallel, args_list))

save_mouth_rois_parallel(custom_df, desc="Custom")

# save_mouth_rois_parallel(test_landmarks_df, desc="Test")

# save_mouth_rois_parallel(val_landmarks_df, desc="Val")
# Out:
# /home/anujm/miniconda3/envs/VSR/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Custom:   0%|          | 0/52 [00:00<?, ?it/s]
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found
# Input buffer exhausted before END element found

# %%
val_df
# Out:
#                                                   path     label  \
# 0     data/lipread_mp4/HUNDREDS/val/HUNDREDS_00041.mp4  HUNDREDS
# 1     data/lipread_mp4/HUNDREDS/val/HUNDREDS_00038.mp4  HUNDREDS
# 2     data/lipread_mp4/HUNDREDS/val/HUNDREDS_00024.mp4  HUNDREDS
# 3     data/lipread_mp4/HUNDREDS/val/HUNDREDS_00019.mp4  HUNDREDS
# 4     data/lipread_mp4/HUNDREDS/val/HUNDREDS_00018.mp4  HUNDREDS
# ...                                                ...       ...
# 2465        data/lipread_mp4/GREAT/val/GREAT_00037.mp4     GREAT
# 2466        data/lipread_mp4/GREAT/val/GREAT_00047.mp4     GREAT
# 2467        data/lipread_mp4/GREAT/val/GREAT_00020.mp4     GREAT
# 2468        data/lipread_mp4/GREAT/val/GREAT_00045.mp4     GREAT
# 2469        data/lipread_mp4/GREAT/val/GREAT_00026.mp4     GREAT
#
#                                               landmarks split
# 0     [[[68.73233, 99.89485], [70.63492, 115.24597],...   val
# 1     [[[36.586792, 97.17292], [40.370026, 114.38685...   val
# 2     [[[41.05754, 104.408066], [43.290985, 122.3381...   val
# 3     [[[66.4197, 80.571625], [67.97587, 97.77672], ...   val
# 4     [[[42.07781, 101.683], [45.211914, 119.02557],...   val
# ...                                                 ...   ...
# 2465  [[[102.616394, 105.323], [101.36221, 120.724],...   val
# 2466  [[[37.591026, 89.17265], [37.82675, 108.63196]...   val
# 2467  [[[66.60347, 101.93374], [67.46085, 118.05652]...   val
# 2468  [[[62.36702, 110.00241], [62.523643, 125.92657...   val
# 2469  [[[49.243683, 105.69214], [50.084137, 122.1657...   val
#
# [1000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

rois = np.load('mouth/roi/ALLEGATIONS/test/WIN_20240226_11_23_28_Pro.npy')

print(len(rois))
def plot_images(images):
    fig = plt.figure(figsize=(10, 10))
    for i in range(20):
        ax = fig.add_subplot(4, 5, i+1)
        ax.imshow(images[i+60], cmap='gray')
        plt.axis('off')
    plt.show()

# Assuming 'images' is your array of images
plot_images(rois)
# Out:
# 85

# %%
import numpy as np
import os 

mouth_path = "mouth/"
mouth_npz = np.load(mouth_path+"mouth_roi.npz")

roi_folder = os.path.join(mouth_path, "roi")

if not os.path.exists(roi_folder):
    os.makedirs(roi_folder)

for item_name in mouth_npz.files:
    label, _ = item_name.split('_')
    filename, split = item_name.split('#')

    label_folder_path = os.path.join(roi_folder, label)
    os.makedirs(label_folder_path, exist_ok=True)

    split_folder_path = os.path.join(label_folder_path, split)
    os.makedirs(split_folder_path, exist_ok=True)

    npy_file_path = os.path.join(split_folder_path, f"{filename}.npy")
    np.save(npy_file_path, arr=mouth_npz[item_name])

# %% [markdown]
# ## Train and Test Functions

# %%
import torch

from typing import Tuple, Dict, List
from tqdm.auto import tqdm

def train_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              optimizer: torch.optim.Optimizer,
              device: torch.device='cpu') -> Tuple[float, float]:

    """This function defines the training step for a model.
    
    Args:
        model (torch.nn.Module): The model that is to be trained.
        dataloader (torch.utils.data.DataLoader): The training dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        optimizer (torch.optim.Optimizer): Optimizer for updating the model parameters.
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the train loss and accuracy for an epoch.

        Example Usage: train_loss, train_acc = train_step(model=model, dataloader=train_dataloader, loss_fn=loss_fn, optimizer=optimizer, device=device)
    """

    model.train()
    train_loss = 0
    train_acc = 0
    
    for batch,(X,y) in enumerate(tqdm(dataloader, desc="Train")):
        X,y = X.to(device), y.to(device)
        X = X.unsqueeze(dim=1)
        X = X.type(torch.float32)
        # Optimizer zero grad
        optimizer.zero_grad()
        # Forward pass
        y_logits = model(X)

        # Calculate loss
        loss = loss_fn(y_logits, y)
        train_loss += loss.item()

        # Back Propagation
        loss.backward()

        # Optimizer Step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_logits, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_logits)

    train_loss = train_loss/len(dataloader)
    train_acc = train_acc/len(dataloader)
    return train_loss, train_acc

# %%
def val_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device='cpu') -> Tuple[float, float]:
    """This function defines the validation step for a model.
    
    Args:
        model (torch.nn.Module): The model that is to be validated.
        dataloader (torch.utils.data.DataLoader): The validation dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the validation loss and accuracy for an epoch.

        Example Usage: val_loss, val_acc = val_step(model=model, dataloader=val_dataloader, loss_fn=loss_fn, device=device)
    """
    model.eval()
    val_loss = 0
    val_acc = 0

    with torch.inference_mode():
        for batch,(X,y) in enumerate(tqdm(dataloader, desc="Val")):
            X,y = X.to(device), y.to(device)
            X = X.unsqueeze(dim=1)
            X = X.type(torch.float32)
            
            # Forward pass
            y_logits = model(X)
    
            # Calculate loss
            loss = loss_fn(y_logits, y)
            val_loss += loss

            # Calculate and accumulate accuracy
            y_labels = y_logits.argmax(dim=1)
            val_acc += ((y_labels == y).sum().item()/len(y_labels))

    val_loss = val_loss/len(dataloader)
    val_acc = val_acc/len(dataloader)
    return val_loss, val_acc

# %%
def train(model: torch.nn.Module,
         train_dataloader: torch.utils.data.DataLoader,
         val_dataloader: torch.utils.data.DataLoader,
         loss_fn: torch.nn.Module,
         optimizer: torch.optim.Optimizer,
         epochs: int = 32,
         device: torch.device = 'cpu') -> Dict[str, List[float]]:
    """This function defines the training functionality of the model.
    
    Args:
        model (torch.nn.Module): The model that is to be trained.
        train_dataloader (torch.utils.data.DataLoader): The training dataloader
        val_dataloader (torch.utils.data.DataLoader): The validation dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        optimizer (torch.optim.Optimizer): Optimizer for updating the model parameters.
        epochs (int): Number of epochs. Default=32
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the train loss and accuracy for an epoch.

        Example Usage: train_loss, train_acc, val_loss, val_acc = train(model=model, train_dataloader=train_dataloader, val_dataloader=val_dataloader, loss_fn=loss_fn,
                                                                        optimizer=optimizer, epochs=32, device=device)
    """
    model_results = {'model_name': model.__class__.__name__,
                    'train_loss': [],
                    'train_acc': [],
                    'val_loss': [],
                    'val_acc': []}
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                dataloader=train_dataloader,
                                loss_fn=loss_fn,
                                optimizer=optimizer,
                                device=device)
        val_loss, val_acc = val_step(model=model,
                           dataloader=val_dataloader,
                           loss_fn=loss_fn,
                           device=device)

        model_results['train_loss'].append(train_loss)
        model_results['train_acc'].append(train_acc)
        model_results['val_loss'].append(val_loss)
        model_results['val_acc'].append(val_acc)
        print(f"Epoch: {epoch} | Train Loss: {train_loss:.2f} | Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.2f} | Val Acc: {val_acc:.2f}%")

    return model_results

# %% [markdown]
# ### Modular

# %%
# %%writefile modular/train.py

"""This module consists of the function required to train the model."""


import torch

from typing import Tuple, Dict, List

def train_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              optimizer: torch.optim.Optimizer,
              device: torch.device='cpu') -> Tuple[float, float]:

    """This function defines the training step for a model.
    
    Args:
        model (torch.nn.Module): The model that is to be trained.
        dataloader (torch.utils.data.DataLoader): The training dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        optimizer (torch.optim.Optimizer): Optimizer for updating the model parameters.
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the train loss and accuracy for an epoch.

        Example Usage: train_loss, train_acc = train_step(model=model, dataloader=train_dataloader, loss_fn=loss_fn, optimizer=optimizer, device=device)
    """

    model.train()
    train_loss = 0
    train_acc = 0
    
    for batch,(X,y) in enumerate(dataloader):
        X,y = X.to(device), y.to(device)

        # Optimizer zero grad
        optimizer.zero_grad()

        # Forward pass
        y_logits = model(X)

        # Calculate loss
        loss = loss_fn(y_logits, y)
        train_loss += loss.item()

        # Back Propagation
        loss.backward()

        # Optimizer Step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_logits, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_logits)

    train_loss = train_loss/len(dataloader)
    train_acc = train_acc/len(dataloader)
    return train_loss, train_acc


def val_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device='cpu') -> Tuple[float, float]:
    """This function defines the validation step for a model.
    
    Args:
        model (torch.nn.Module): The model that is to be validated.
        dataloader (torch.utils.data.DataLoader): The validation dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the validation loss and accuracy for an epoch.

        Example Usage: val_loss, val_acc = val_step(model=model, dataloader=val_dataloader, loss_fn=loss_fn, device=device)
    """
    model.eval()
    val_loss = 0
    val_acc = 0

    with torch.inference_mode():
        for batch,(X,y) in enumerate(dataloader):
            X,y = X.to(device), y.to(device)
    
            # Forward pass
            y_logits = model(X)
    
            # Calculate loss
            loss = loss_fn(y_logits, y)
            val_loss += loss

            # Calculate and accumulate accuracy
            y_labels = y_logits.argmax(dim=1)
            val_acc += ((y_labels == y).sum().item()/len(y_labels))

    val_loss = val_loss/len(dataloader)
    val_acc = val_acc/len(dataloader)
    return val_loss, val_acc


def train(model: torch.nn.Module,
         train_dataloader: torch.utils.data.DataLoader,
         val_dataloader: torch.utils.data.DataLoader,
         loss_fn: torch.nn.Module,
         optimizer: torch.optim.Optimizer,
         epochs: int = 32,
         device: torch.device = 'cpu') -> Dict[str, List[float]]:
    """This function defines the training functionality of the model.
    
    Args:
        model (torch.nn.Module): The model that is to be trained.
        train_dataloader (torch.utils.data.DataLoader): The training dataloader
        val_dataloader (torch.utils.data.DataLoader): The validation dataloader
        loss_fn (torch.nn.Module): Loss function to evaluate the model
        optimizer (torch.optim.Optimizer): Optimizer for updating the model parameters.
        epochs (int): Number of epochs. Default=32
        device (torch.device): The device used to train the model. Default='cpu'

    Returns:
        A tuple consisting the train loss and accuracy for an epoch.

        Example Usage: train_loss, train_acc, val_loss, val_acc = train(model=model, train_dataloader=train_dataloader, val_dataloader=val_dataloader, loss_fn=loss_fn,
                                                                        optimizer=optimizer, epochs=32, device=device)
    """
    model_results = {'model_name': model.__class__.__name__,
                    'train_loss': [],
                    'train_acc': [],
                    'val_loss': [],
                    'val_acc': []}
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                dataloader=train_dataloader,
                                loss_fn=loss_fn,
                                optimizer=optimizer,
                                device=device)
        val_loss, val_acc = val_step(model=model,
                           dataloader=val_dataloader,
                           loss_fn=loss_fn,
                           device=device)

        model_results['train_loss'].append(train_loss)
        model_results['train_acc'].append(train_acc)
        model_results['val_loss'].append(val_loss)
        model_results['val_acc'].append(val_acc)
        print(f"Epoch: {epoch} | Train Loss: {train_loss:.2f} | Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.2f} | Val Acc: {val_acc:.2f}%")

    return model_results
# Out:
# Overwriting modular/train.py

# %% [markdown]
# ## Dataset and Dataloader

# %%
from torch.utils.data import Dataset

class LRWDataset(Dataset):
    def __init__(self, df, transforms=None):
        self.df = df
        self.transforms = transforms

        self.classes = self.df['label'].unique()
        self.class_to_idx = {classname: idx for idx, classname in enumerate(self.classes)}

    def get_mouth_roi(self, path):
        tokens = path.split('/')
        label, split, filename = tokens[-3:]
        filename = filename.split('.')[0]

        roi = np.load(os.path.join('mouth/roi/', label, split, filename+'.npy'))
        return roi, label

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        path = self.df.iloc[idx]['path']
        roi, label = self.get_mouth_roi(str(path))
        class_idx = self.class_to_idx[label]

        if self.transforms:
            return self.transforms(roi), class_idx

        return roi, class_idx

# %%
import pandas as pd

train_df = pd.read_pickle("dataframe/train_df_50lab_1000train_50val_50test.pkl")
test_df = pd.read_pickle("dataframe/test_df_100lab_1000train_50val_50test.pkl")
val_df = pd.read_pickle("dataframe/val_df_50lab_1000train_50val_50test.pkl")

# %%
train_data = LRWDataset(df=train_df)
test_data = LRWDataset(df=test_df)
val_data = LRWDataset(df=val_df)

# %%
from torch.utils.data import DataLoader

class PrefetchDataLoader(DataLoader):
    def __iter__(self):
        self._iterator = super().__iter__()

        self._prefetch()

        return self

    def _prefetch(self):
        try:
            self._prefetched_batch = next(self._iterator)
        except StopIteration:
            self._prefetched_batch = None

    def __next__(self):
        # Get the current batch
        batch = self._prefetched_batch

        # Prefetch the next batch
        self._prefetch()

        return batch

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 32
NUM_WORKERS = 4

train_dataloader = DataLoader(dataset=train_data,
                             num_workers=NUM_WORKERS,
                             shuffle=True,
                             pin_memory=True,
                             batch_size=BATCH_SIZE)

test_dataloader = DataLoader(dataset=test_data,
                            num_workers=NUM_WORKERS,
                            shuffle=False,
                            batch_size=BATCH_SIZE)


val_dataloader = DataLoader(dataset=val_data,
                            num_workers=NUM_WORKERS,
                            shuffle=False,
                            batch_size=BATCH_SIZE,
                            pin_memory=True)

# %%
next(iter(train_dataloader))[0].shape
# Out:
# torch.Size([32, 29, 96, 96])

# %% [markdown]
# ## Create Model

# %% [markdown]
# ### Baseline Model

# %%
class LipReadingModel(nn.Module):
    def __init__(self, num_classes=50):
        super(LipReadingModel, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv3d(1, 64, kernel_size=(3, 5, 5), stride=(1, 2, 2), padding=(1, 2, 2))
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2))
        
        self.conv2 = nn.Conv3d(64, 128, kernel_size=(3, 5, 5), stride=(1, 2, 2), padding=(1, 2, 2))
        self.relu2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2))
        
        # Fully connected layers
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(128 * 6 * 6 * 29, 512)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        # Input shape: (batch_size, channels, frames, height, width)
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)
        
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)
        
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.relu3(x)
        logits = self.fc2(x)
        
        return logits

model_0 = LipReadingModel().to(device)

# %%
from torchinfo import summary

summary(model_0, input_size=[32,1,29,96,96])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LipReadingModel                          [32, 50]                  --
# ├─Conv3d: 1-1                            [32, 64, 29, 48, 48]      4,864
# ├─ReLU: 1-2                              [32, 64, 29, 48, 48]      --
# ├─MaxPool3d: 1-3                         [32, 64, 29, 24, 24]      --
# ├─Conv3d: 1-4                            [32, 128, 29, 12, 12]     614,528
# ├─ReLU: 1-5                              [32, 128, 29, 12, 12]     --
# ├─MaxPool3d: 1-6                         [32, 128, 29, 6, 6]       --
# ├─Flatten: 1-7                           [32, 133632]              --
# ├─Linear: 1-8                            [32, 512]                 68,420,096
# ├─ReLU: 1-9                              [32, 512]                 --
# ├─Linear: 1-10                           [32, 50]                  25,650
# ==========================================================================================
# Total params: 69,065,138
# Trainable params: 69,065,138
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 94.71
# ==========================================================================================
# Input size (MB): 34.21
# Forward/backward pass size (MB): 1231.70
# Params size (MB): 276.26
# Estimated Total Size (MB): 1542.17
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.01)

# %%
train(model=model_0, train_dataloader=train_dataloader, val_dataloader=val_dataloader, loss_fn=loss_fn, optimizer=optimizer, device=device, epochs=10)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Train:   0%|          | 0/1531 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train(model=model_0, train_dataloader=train_dataloader, val_dataloader=val_dataloader, loss_fn=loss_fn, optimizer=optimizer, device=device, epochs=10)
#
# Cell In[5], line 31, in train(model, train_dataloader, val_dataloader, loss_fn, optimizer, epochs, device)
#      25 model_results = {'model_name': model.__class__.__name__,
#      26                 'train_loss': [],
#      27                 'train_acc': [],
#      28                 'val_loss': [],
#      29                 'val_acc': []}
#      30 for epoch in tqdm(range(epochs)):
# ---> 31     train_loss, train_acc = train_step(model=model,
#      32                             dataloader=train_dataloader,
#      33                             loss_fn=loss_fn,
#      34                             optimizer=optimizer,
#      35                             device=device)
#      36     val_loss, val_acc = val_step(model=model,
#      37                        dataloader=val_dataloader,
#      38                        loss_fn=loss_fn,
#      39                        device=device)
#      41     model_results['train_loss'].append(train_loss)
#
# Cell In[3], line 31, in train_step(model, dataloader, loss_fn, optimizer, device)
#      28 train_loss = 0
#      29 train_acc = 0
# ---> 31 for batch,(X,y) in enumerate(tqdm(dataloader, desc="Train")):
#      32     X,y = X.to(device), y.to(device)
#      33     X = X.unsqueeze(dim=1)
#
# TypeError: cannot unpack non-iterable NoneType object
